# %% [markdown]
# ## 1. Install Beberapa Library Terlebih Dahulu

# %%
# Install library nltk (natural language tool-kit)
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\ekapr\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\ekapr\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\ekapr\anaconda3\lib\site-packages (from nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ekapr\anaconda3\lib\site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: joblib in c:\users\ekapr\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: colorama in c:\users\ekapr\anaconda3\lib\site-packages (from click->nltk) (0.4.4)

# %%
# Install library WordCloud. Library ini untuk membuat visualisasi kumpulan-kumpulan teks
# !pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\ekapr\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: pillow in c:\users\ekapr\anaconda3\lib\site-packages (from WordCloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ekapr\anaconda3\lib\site-packages (from WordCloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\ekapr\anaconda3\lib\site-packages (from WordCloud) (3.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ekapr\anaconda3\lib\site-packages (from matplotlib->WordCloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ekapr\anaconda3\lib\site-packages (from matplotlib->WordCloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ekapr\anaconda3\lib\site-packages (from matplotlib->WordCloud) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ekapr\anaconda3\lib\site-packages (from matplotlib->WordCloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ekapr\anaconda3\lib\site-packages (from matplotlib->WordCloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ekapr\anaconda3\lib\site-packages (from matplotlib->WordCloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\ekapr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.16.0)

# %%
"""
Install library regex. Library ini bertujuan untuk mengubah bentuk
string dan bisa menghilangkan/membersihkan teks dari simbol-simbol, emoticon, dll
"""
# !pip install regex
# Out:
# Requirement already satisfied: regex in c:\users\ekapr\anaconda3\lib\site-packages (2022.3.15)

# %%
"""
Install library Sastrawi. 
Library ini bertujuan untuk mengubah kata-kata yang memiliki imbuhan bahasa Indonesia menjadi bentuk dasarnya
"""
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\ekapr\anaconda3\lib\site-packages (1.0.1)

# %%
"""
Install library swifter. Library ini berfungsi untuk mempercepat proses stemming
terhadap DataFrame ketika menjalankan pemrosesan secara parallel
"""
# !pip install swifter
# Out:
# Requirement already satisfied: swifter in c:\users\ekapr\anaconda3\lib\site-packages (1.1.3)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (4.64.0)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (5.8.0)
# Requirement already satisfied: parso>0.4.0 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (0.8.3)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (1.4.2)
# Requirement already satisfied: bleach>=3.1.1 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (4.1.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (2.0.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (7.6.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\ekapr\anaconda3\lib\site-packages (from swifter) (2022.2.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\ekapr\anaconda3\lib\site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: packaging in c:\users\ekapr\anaconda3\lib\site-packages (from bleach>=3.1.1->swifter) (21.3)
# Requirement already satisfied: webencodings in c:\users\ekapr\anaconda3\lib\site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ekapr\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\ekapr\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.2.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\ekapr\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Requirement already satisfied: partd>=0.3.10 in c:\users\ekapr\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\ekapr\anaconda3\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ekapr\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->swifter) (6.9.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ekapr\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->swifter) (8.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->swifter) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->swifter) (1.0.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.1)
# Requirement already satisfied: nest-asyncio in c:\users\ekapr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\ekapr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.11.2)
# Requirement already satisfied: colorama in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: backcall in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (61.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: decorator in c:\users\ekapr\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ekapr\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\ekapr\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\ekapr\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ekapr\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (302)
# Requirement already satisfied: fastjsonschema in c:\users\ekapr\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ekapr\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ekapr\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ekapr\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ekapr\anaconda3\lib\site-packages (from packaging->bleach>=3.1.1->swifter) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ekapr\anaconda3\lib\site-packages (from pandas>=1.0.0->swifter) (2021.3)
# Requirement already satisfied: locket in c:\users\ekapr\anaconda3\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (0.2.1)
# Requirement already satisfied: wcwidth in c:\users\ekapr\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\ekapr\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: jinja2 in c:\users\ekapr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ekapr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\ekapr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (6.4.4)
# Requirement already satisfied: prometheus-client in c:\users\ekapr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.13.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ekapr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\ekapr\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ekapr\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ekapr\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ekapr\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ekapr\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ekapr\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.13)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: testpath in c:\users\ekapr\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (0.5.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ekapr\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->swifter) (2.3.1)
# Requirement already satisfied: asttokens in c:\users\ekapr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ekapr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: executing in c:\users\ekapr\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.3)

# %% [markdown]
# ## 2. Import Library dan Eksplorasi Dataset Menggunakan Pandas

# %%
# Import Library
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
import re
import nltk
nltk.download("punkt")
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize
from sklearn.metrics import confusion_matrix, classification_report
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ekapr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Read dataset yang telah dicrawling (diambil) dari media sosial twitter dan menampilkan data sebanyak 17 data teratas
data_hepatitis = pd.read_csv("Data Crawling Hepatitis Akut/Tweet_Hepatitis_with_Label_TextBlob.csv")

data_hepatitis.head(17)
# Out:
#             Waktu Tweet                   Username  \
# 0   2022-06-26 16:16:08  ⚕️base anak fk | open dm📩
# 1   2022-06-26 14:02:24           billion store id
# 2   2022-06-26 12:19:45                    lyndsay
# 3   2022-06-26 12:19:42                    lyndsay
# 4   2022-06-26 12:17:25                    lyndsay
# 5   2022-06-26 11:20:51                   syaza 🇲🇾
# 6   2022-06-26 11:17:15        jengkelin say no 🚫💉
# 7   2022-06-26 11:08:07            rs pondok indah
# 8   2022-06-26 11:07:32                          🦋
# 9   2022-06-26 11:05:22                       nawa
# 10  2022-06-26 10:20:14              ᗰᗩᗪᗩᗰ ᑎᘜᗴ̄ᕼᗴ̄
# 11  2022-06-26 09:24:49           jangantungguhaus
# 12  2022-06-26 09:12:36                  inisial d
# 13  2022-06-26 08:36:42                hendi putra
# 14  2022-06-26 08:18:06                       lina
# 15  2022-06-26 07:23:35             pikiran rakyat
# 16  2022-06-26 07:10:33                   oke zone
#
#                                                 Tweet  Sentimen
# 0   dok mau tanyaaa kalo misalnya tes hepatitis se...   Neutral
# 1   terbaik teraman supplement kesehatan kapsul sp...  Positive
# 2   ketua dpr puan maharani menyoroti sejumlah hal...  Positive
# 3   puan yang menyoroti hepatitis dan berbagai mac...   Neutral
# 4   puan menyoroti kasus hepatitis akut anak harga...  Positive
# 5   ambil ujian darah doktor kata darah semua cant...  Positive
# 6   vaksin gak pernah salah jadi katakan saja itu ...  Positive
# 7   sempat ramai beberapa waktu lalu hepatitis mis...  Positive
# 8                             mulan hepatitis gunung    Neutral
# 9   byeeee semua bye gue udah stres minggu sama ke...   Neutral
# 10   gila dan itu mmg benar banyak anak2 sudah vak...  Negative
# 11   rilissehat patogen ini paling banyak ditemuka...   Neutral
# 12   kalau perawatan kecantikan udah sering dibaha...  Positive
# 13  genjot vaksinasi booster binda jateng vaksinas...  Positive
# 14  hepatitis tidak terkait dengan vaksin vaksin 1...  Positive
# 15  who peringatkan hepatitis misterius pada anak ...   Neutral
# 16  hepatitis akut masih mengintai bunda ini cara ...  Positive

# %%
# Melihat ukuran seperti jumlah kolom dan baris dari DataFrame "data_hepatitis"
data_hepatitis.shape
# Out:
# (899, 4)

# %%
# Melihat tipe data dari DataFrame "data_hepatitis"
data_hepatitis.dtypes
# Out:
# Waktu Tweet    object
# Username       object
# Tweet          object
# Sentimen       object
# dtype: object

# %%
# Melihat apakah di dalam DataFrame "data_hepatitis" memiliki missing values/tidak
data_hepatitis.isna()
# Out:
#      Waktu Tweet  Username  Tweet  Sentimen
# 0          False     False  False     False
# 1          False     False  False     False
# 2          False     False  False     False
# 3          False     False  False     False
# 4          False     False  False     False
# ..           ...       ...    ...       ...
# 894        False     False  False     False
# 895        False     False  False     False
# 896        False     False  False     False
# 897        False     False  False     False
# 898        False     False  False     False
#
# [899 rows x 4 columns]

# %%
# Melihat informasi yang terkandung di dalam DataFrame "data_hepatitis"
data_hepatitis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Waktu Tweet  899 non-null    object
#  1   Username     899 non-null    object
#  2   Tweet        899 non-null    object
#  3   Sentimen     899 non-null    object
# dtypes: object(4)
# memory usage: 28.2+ KB

# %% [markdown]
# Berdasarkan output dari informasi yang ada di dalam "data_hepatitis" maka dapat diambil beberapa kesimpulan diantaranya adalah sebagai berikut:
#
# 1. Jumlah baris yang ada di dalam DataFrame "data_hepatitis" yakni sebanyak 899 data dengan 4 kolom.
# 2. Setiap kolom yang ada di dalam DataFrame "data_hepatitis" tidak memiliki missing values/nilai kosong.
# 3. Tipe data yang digunakan pada DataFrame "data_hepatitis" hanya object (string) saja.

# %%
"""
Melihat jumlah nilai sekaligus data-data apa saja yang ada 
di dalam kolom "Waktu Tweet", "Username", dan "Sentimen"
"""

print("--------------Jumlah Total Nilai Data Pada Kolom Waktu Tweet--------------")
print(data_hepatitis["Waktu Tweet"].value_counts(), "\n")

print("--------------Jumlah Total Nilai Data Pada Kolom Username--------------")
print(data_hepatitis["Username"].value_counts(), "\n")

print("--------------Jumlah Total Nilai Data Pada Kolom Sentimen--------------")
print(data_hepatitis["Sentimen"].value_counts())
# Out:
# --------------Jumlah Total Nilai Data Pada Kolom Waktu Tweet--------------
# 2022-06-19 05:55:41    2
# 2022-06-19 11:42:28    2
# 2022-06-19 11:42:29    2
# 2022-06-22 07:20:48    2
# 2022-06-24 02:05:59    2
#                       ..
# 2022-06-24 02:28:17    1
# 2022-06-24 02:27:38    1
# 2022-06-24 02:26:50    1
# 2022-06-24 02:22:18    1
# 2022-06-17 01:45:06    1
# Name: Waktu Tweet, Length: 894, dtype: int64
#
# --------------Jumlah Total Nilai Data Pada Kolom Username--------------
# anissa billa                           14
# yuni marisa                            10
# sutansegeh                             10
# putri                                  10
# luis chaniago                           9
#                                        ..
# goodman                                 1
# epidemiology job openings (epijobs)     1
# mune 🌙                                  1
# kalla jengking                          1
# sunday🌏                                 1
# Name: Username, Length: 514, dtype: int64
#
# --------------Jumlah Total Nilai Data Pada Kolom Sentimen--------------
# Positive    558
# Neutral     243
# Negative     98
# Name: Sentimen, dtype: int64

# %% [markdown]
# Berdasarkan hasil output diatas maka dapat diambil contoh penjelasan dari dua kolom (Username dan Sentimen) yang diantaranya adalah sebagai berikut:
#
#
# 1. Pada kolom "Username", nilai yang sering muncul di dalam DataFrame "data_hepatitis" adalah username yang bernama annisa billa dengan nilai kemunculan sebanyak 14 kali yang kemudian disusul dengan username yang bernama yuni marisa yang memiliki nilai kemunculan sebanyak 10 kali, sedangkan username yang jarang terlihat pada DataFrame "data" adalah goodman, epidemiology job openings (epijobs), mune 🌙, kalla jengking, dan sunday🌏 yang memiliki nilai kemunculan hanya sebanyak satu kali saja dalam meng-tweet topik tentang hepatitis akut.
# 2. Pada kolom "Sentimen", nilai yang sering muncul di dalam kolom ini yaitu sentimen Positive dengan nilai kemunculan sebanyak 558 kali yang kemudian disusul oleh sentimen Neutral (Netral) sebanyak 243 kali, sedangkan sentimen Negative (Negatif) memiliki total nilai kemunculan sebanyak 98 kali di dalam DataFrame "data_hepatitis".

# %%
# Melihat nilai statistik deskriptif dari DataFrame "data_hepatitis" untuk semua kolom
data_hepatitis.describe(include="all")
# Out:
#                 Waktu Tweet      Username  \
# count                   899           899
# unique                  894           514
# top     2022-06-19 05:55:41  anissa billa
# freq                      2            14
#
#                                                     Tweet  Sentimen
# count                                                 899       899
# unique                                                899         3
# top     dok mau tanyaaa kalo misalnya tes hepatitis se...  Positive
# freq                                                    1       558

# %% [markdown]
# Berdasarkan hasil diatas dapat diketahui nilai-nilai statistik deskriptif dari keempat kolom pada DataFrame "data_hepatitis". Di samping itu, karena keempat kolom ini bersifat kategorik bukan numerik maka nilai statistik deskriptif yang ditampilkan berbeda daripada nilai statistik deskriptif untuk kolom yang bersifat numerik karena nilai statistik deskriptif untuk kolom yang bersifat numerik adalah mean, std (standard deviasi), quartil 1 (25%), quartil 2/median (50%), quartil 3 (75%), min (minimum), dan max (maximum), sedangkan untuk kolom kategorik memiliki nilai statistik deskriptif yaitu nilai unique, top, dan freq.
#
# Nilai unique merupakan total nilai/data yang berbeda di dalam 1 kolom. Nilai top merupakan nilai yang sering muncul di dalam kolom tersebut. Terakhir adalah nilai freq yang merupakan total nilai pada nilai top. Sebagai contoh nilai top pada kolom "Sentimen" adalah Positive yang memiliki total kemunculan di dalam kolom tersebut sebanyak 558 data. Hal tersebut sama seperti di codingan sebelumnya ketika saya ingin melihat jumlah nilai dari masing-masing kolom di dalam DataFrame "data_hepatitis". Berikut adalah penjelasan untuk masing-masing nilai statistik deskriptif dari kolom Waktu Tweet, Username, dan Sentimen berdasarkan hasil statistik deskriptif diatas:
#
#
# 1. Pada kolom "Waktu Tweet" memiliki nilai unique berjumlah 894 dengan nilai top/nilai yang sering terlihat adalah 2022-06-19 05:55:41 dengan nilai freq atau nilai kemunculan sebanyak 2 kali.
# 2. Kolom "Username" memiliki nilai top adalah anissa billa dengan jumlah nilai kemunculan sebanyak 14 kali. Selain itu, kolom "Username" memiliki 514 nilai data yang berbeda-beda.
# 3. Terakhir adalah kolom "Sentimen" yang memiliki nilai unique hanya 3 saja dan dari ketiga nilai tersebut terdapat nilai top/nilai yang sering muncul di dalam kolom "Sentimen" adalah sentimen Positive yang memiliki total nilai kemunculan (nilai freq) sebanyak 558 kali.

# %% [markdown]
# ## 3. Text Preprocessing

# %% [markdown]
# ### 3.1. Cleansing Text

# %% [markdown]
# Text preprocessing pertama yang saya lakukan yaitu membersihkan isi tweet yang memiliki simbol-simbol seperti !”#$%&’()*+,-./:;<=>?@[]^_`{|}~]

# %%
"""
Menghilangkan huruf-huruf yang tidak sesuai, simbol-simbol, dan emoticon yang tidak dibutuhkan 
di dalam kolom "Username" dan "Tweet" dan menampilkan data sebanyak 15 data teratas
"""
def cleansing_text(text):
    text = re.sub(r"[^a-zA-z0-9]", " ", str(text))
    text = re.sub(r"\b\w{1,2}\b", "", text)
    text = re.sub(r"\s\s+", " ", text)
    text = re.sub(r"https?:\/\/\S+", "", text)  
    text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", text)
    return text

data_hepatitis["Username"] = data_hepatitis["Username"].apply(cleansing_text)
data_hepatitis["Tweet"] = data_hepatitis["Tweet"].apply(cleansing_text)

data_hepatitis.head(15)
# Out:
#             Waktu Tweet          Username  \
# 0   2022-06-26 16:16:08   base anak open
# 1   2022-06-26 14:02:24    billion store
# 2   2022-06-26 12:19:45           lyndsay
# 3   2022-06-26 12:19:42           lyndsay
# 4   2022-06-26 12:17:25           lyndsay
# 5   2022-06-26 11:20:51            syaza
# 6   2022-06-26 11:17:15    jengkelin say
# 7   2022-06-26 11:08:07      pondok indah
# 8   2022-06-26 11:07:32
# 9   2022-06-26 11:05:22              nawa
# 10  2022-06-26 10:20:14
# 11  2022-06-26 09:24:49  jangantungguhaus
# 12  2022-06-26 09:12:36          inisial
# 13  2022-06-26 08:36:42       hendi putra
# 14  2022-06-26 08:18:06              lina
#
#                                                 Tweet  Sentimen
# 0   dok mau tanyaaa kalo misalnya tes hepatitis se...   Neutral
# 1   terbaik teraman supplement kesehatan kapsul sp...  Positive
# 2   ketua dpr puan maharani menyoroti sejumlah hal...  Positive
# 3   puan yang menyoroti hepatitis dan berbagai mac...   Neutral
# 4   puan menyoroti kasus hepatitis akut anak harga...  Positive
# 5   ambil ujian darah doktor kata darah semua cant...  Positive
# 6   vaksin gak pernah salah jadi katakan saja itu ...  Positive
# 7   sempat ramai beberapa waktu lalu hepatitis mis...  Positive
# 8                             mulan hepatitis gunung    Neutral
# 9   byeeee semua bye gue udah stres minggu sama ke...   Neutral
# 10   gila dan itu mmg benar banyak anak2 sudah vak...  Negative
# 11   rilissehat patogen ini paling banyak ditemuka...   Neutral
# 12   kalau perawatan kecantikan udah sering dibaha...  Positive
# 13  genjot vaksinasi booster binda jateng vaksinas...  Positive
# 14  hepatitis tidak terkait dengan vaksin vaksin 1...  Positive

# %% [markdown]
# Setelah melakukan proses pembersihan tweet terhadap simbol-simbol atau karakter-karakter yang tidak dipentingkan, langkah selanjutnya adalah case folding. Case folding merupakan sebuah tahapan untuk mengubah huruf-huruf kapital menjadi huruf-huruf kecil seperti dari huruf "A - Z" menjadi "a - z".

# %% [markdown]
# ### 3.2. Case Folding

# %%
# Mengubah ukuran setiap kalimat yang ada di kolom "Tweet" menjadi huruf kecil dan menampilkan data sebanyak 7 data terbawah
data_hepatitis["Tweet Case Folding"] = data_hepatitis["Tweet"].str.lower()

data_hepatitis.tail(7)
# Out:
#              Waktu Tweet       Username  \
# 892  2022-06-17 02:14:14      hermionne
# 893  2022-06-17 02:12:54  anisa cenceni
# 894  2022-06-17 02:12:14       suparman
# 895  2022-06-17 02:09:13     snow white
# 896  2022-06-17 02:03:05   dindu nuffin
# 897  2022-06-17 02:00:00   duah menaria
# 898  2022-06-17 01:45:06        sunday
#
#                                                  Tweet  Sentimen  \
# 892  ikn sejahterakan negeri waspada disinformasi d...   Neutral
# 893   disinformasi vaksin mrna menyebabkan hepatiti...   Neutral
# 894  tidak benar jika vaksin menyebabkan hepatitis ...  Negative
# 895  vaksin astrazeneca bukan pemicu hepatitis akut...  Positive
# 896  kandungan adenovirus pada vaksin covid bukan p...   Neutral
# 897  vaksin covid anak aman waspada provokasi kelom...  Positive
# 898  sini konten nct datang aja barengan gue gak ta...  Positive
#
#                                     Tweet Case Folding
# 892  ikn sejahterakan negeri waspada disinformasi d...
# 893   disinformasi vaksin mrna menyebabkan hepatiti...
# 894  tidak benar jika vaksin menyebabkan hepatitis ...
# 895  vaksin astrazeneca bukan pemicu hepatitis akut...
# 896  kandungan adenovirus pada vaksin covid bukan p...
# 897  vaksin covid anak aman waspada provokasi kelom...
# 898  sini konten nct datang aja barengan gue gak ta...

# %% [markdown]
# Setelah melakukan proses case folding, langkah selanjutnya adalah tokenizing/tokenisasi. Tahap tokenizing merupakan tahap pemotongan teks ke dalam satuan kata atau bisa dikatakan memotong susunan kalimat menjadi kata per kata atau potongan-potongan kata yang akan dianalisis.

# %% [markdown]
# ### 3.3. Tokenizing

# %%
"""
Melakukan tahap tokenizing atau tokenisasi. Tokenizing merupakan tahapan text preprocessing 
yang digunakan untuk memecah atau memotong susunan kalimat menjadi kata per kata dari kolom Tweet Case Folding
dan menampilkan data sebanyak 8 data teratas
"""
def tokenizing(text):
    return word_tokenize(text)

data_hepatitis["Tweet Tokenizing"] = data_hepatitis["Tweet Case Folding"].apply(tokenizing)
data_hepatitis.head(8)
# Out:
#            Waktu Tweet          Username  \
# 0  2022-06-26 16:16:08   base anak open
# 1  2022-06-26 14:02:24    billion store
# 2  2022-06-26 12:19:45           lyndsay
# 3  2022-06-26 12:19:42           lyndsay
# 4  2022-06-26 12:17:25           lyndsay
# 5  2022-06-26 11:20:51            syaza
# 6  2022-06-26 11:17:15    jengkelin say
# 7  2022-06-26 11:08:07      pondok indah
#
#                                                Tweet  Sentimen  \
# 0  dok mau tanyaaa kalo misalnya tes hepatitis se...   Neutral
# 1  terbaik teraman supplement kesehatan kapsul sp...  Positive
# 2  ketua dpr puan maharani menyoroti sejumlah hal...  Positive
# 3  puan yang menyoroti hepatitis dan berbagai mac...   Neutral
# 4  puan menyoroti kasus hepatitis akut anak harga...  Positive
# 5  ambil ujian darah doktor kata darah semua cant...  Positive
# 6  vaksin gak pernah salah jadi katakan saja itu ...  Positive
# 7  sempat ramai beberapa waktu lalu hepatitis mis...  Positive
#
#                                   Tweet Case Folding  \
# 0  dok mau tanyaaa kalo misalnya tes hepatitis se...
# 1  terbaik teraman supplement kesehatan kapsul sp...
# 2  ketua dpr puan maharani menyoroti sejumlah hal...
# 3  puan yang menyoroti hepatitis dan berbagai mac...
# 4  puan menyoroti kasus hepatitis akut anak harga...
# 5  ambil ujian darah doktor kata darah semua cant...
# 6  vaksin gak pernah salah jadi katakan saja itu ...
# 7  sempat ramai beberapa waktu lalu hepatitis mis...
#
#                                     Tweet Tokenizing
# 0  [dok, mau, tanyaaa, kalo, misalnya, tes, hepat...
# 1  [terbaik, teraman, supplement, kesehatan, kaps...
# 2  [ketua, dpr, puan, maharani, menyoroti, sejuml...
# 3  [puan, yang, menyoroti, hepatitis, dan, berbag...
# 4  [puan, menyoroti, kasus, hepatitis, akut, anak...
# 5  [ambil, ujian, darah, doktor, kata, darah, sem...
# 6  [vaksin, gak, pernah, salah, jadi, katakan, sa...
# 7  [sempat, ramai, beberapa, waktu, lalu, hepatit...

# %% [markdown]
# Setelah melakukan tahapan tokenisasi (tokenizing), selanjutnya saya akan melakukan proses filtering (stowords). Proses stopwords ini merupakan tahapan pengambilan kata-kata dari tahapan tokenisasi. Stopword merupakan sebuah tahapan yang dimana bertujuan untuk membuang kata-kata yang tidak deskriptif dalam melakukan pendekatan bag-of-words.
#
# Kata-kata yang termasuk ke dalam list stopwords Bahasa Indonesia adalah sebagai berikut:
#
# "yang", "untuk", "pada", "ke", "para", "namun", "menurut", "antara", "dia", "dua", "ia", "seperti", "jika", "jika", "sehingga", "kembali", "dan", "tidak", "ini", "karena", "kepada", "oleh", "saat", "harus", "sementara", "setelah", "belum", "kami", "sekitar", "bagi", "serta", "di", "dari", "telah", "sebagai", "masih", "hal", "ketika", "adalah", "itu", "dalam", "bisa", "bahwa", "atau", "hanya", "kita", "dengan", "akan", "juga", "ada", "mereka", "sudah", "saya", "terhadap", "secara", "agar", "lain", "anda", "begitu", "mengapa", "kenapa", "yaitu", "yakni", "daripada", "itulah", "lagi", "maka", "tentang", "demi", "dimana", "kemana", "pula", "sambil", "sebelum", "sesudah", "supaya", "guna", "kah", "pun", "sampai", "sedangkan", "selagi", "sementara", "tetapi", "apakah", "kecuali", "sebab", "selain", "seolah", "seraya", "seterusnya", "tanpa", "agak", "boleh", "dapat", "dsb", "dst", "dll", "dahulu", "dulunya", "anu", "demikian", "tapi", "ingin", "juga", "nggak", "mari", "nanti", "melainkan", "oh", "ok", "seharusnya", "sebetulnya", "setiap", "setidaknya", "sesuatu", "pasti", "saja", "toh", "ya", "walau", "tolong", "tentu", "amat", "apalagi", dan "bagaimanapun".
#
# Kata-kata tersebut dapat dilihat atau diketahui melalui library Sastrawi. Tahapan dari stopwords dapat dilihat pada langkah selanjutnya.

# %% [markdown]
# ### 3.4. Stopwords

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
 
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
print(stopwords)
# Out:
# ['yang', 'untuk', 'pada', 'ke', 'para', 'namun', 'menurut', 'antara', 'dia', 'dua', 'ia', 'seperti', 'jika', 'jika', 'sehingga', 'kembali', 'dan', 'tidak', 'ini', 'karena', 'kepada', 'oleh', 'saat', 'harus', 'sementara', 'setelah', 'belum', 'kami', 'sekitar', 'bagi', 'serta', 'di', 'dari', 'telah', 'sebagai', 'masih', 'hal', 'ketika', 'adalah', 'itu', 'dalam', 'bisa', 'bahwa', 'atau', 'hanya', 'kita', 'dengan', 'akan', 'juga', 'ada', 'mereka', 'sudah', 'saya', 'terhadap', 'secara', 'agar', 'lain', 'anda', 'begitu', 'mengapa', 'kenapa', 'yaitu', 'yakni', 'daripada', 'itulah', 'lagi', 'maka', 'tentang', 'demi', 'dimana', 'kemana', 'pula', 'sambil', 'sebelum', 'sesudah', 'supaya', 'guna', 'kah', 'pun', 'sampai', 'sedangkan', 'selagi', 'sementara', 'tetapi', 'apakah', 'kecuali', 'sebab', 'selain', 'seolah', 'seraya', 'seterusnya', 'tanpa', 'agak', 'boleh', 'dapat', 'dsb', 'dst', 'dll', 'dahulu', 'dulunya', 'anu', 'demikian', 'tapi', 'ingin', 'juga', 'nggak', 'mari', 'nanti', 'melainkan', 'oh', 'ok', 'seharusnya', 'sebetulnya', 'setiap', 'setidaknya', 'sesuatu', 'pasti', 'saja', 'toh', 'ya', 'walau', 'tolong', 'tentu', 'amat', 'apalagi', 'bagaimanapun']

# %% [markdown]
# Berdasarkan output diatas dapat diketahui bahwasanya Bahasa Indonesia memiliki banyak sekali kata imbuhan seperti kata "yang", "untuk", "pada", dst. Dalam pengujian natural language processing (NLP) biasanya tidak terlalu membutuhkan kata-kata imbuhan. Maka dari itu sebelum melakukan proses pengklasifikasian dengan model machine learning, terlebih dahulu text yang memiliki kata-kata imbuhan dihapus dari daftar teks.

# %%
# Melakukan tahap stopwords yaitu menghapus kata-kata imbuhan dari kolom "Tweet Tokenizing"
from nltk.corpus import stopwords
nltk.download("stopwords")

# Mendeklarasikan kata-kata imbuhan Bahasa Indonesia yang akan dihapus
remove_affixes = ["yang", "untuk", "pada", "ke", "para", "namun", "menurut", "antara", "dia", "dua", "ia",
                  "seperti", "jika", "jika", "sehingga", "kembali", "dan", "tidak", "ini", "karena", "kepada", "oleh",
                  "saat", "harus", "sementara", "setelah", "belum", "kami", "sekitar", "bagi", "serta", "di", "dari", "telah",
                  "sebagai", "masih", "hal", "ketika", "adalah", "itu", "dalam", "bisa", "bahwa", "atau", "hanya", "kita",
                  "dengan", "akan", "juga", "ada", "mereka", "sudah", "saya", "terhadap", "secara", "agar", "lain", "anda",
                  "begitu", "mengapa", "kenapa", "yaitu", "yakni", "daripada", "itulah", "lagi", "maka", "tentang", "demi",
                  "dimana", "kemana", "pula", "sambil", "sebelum", "sesudah", "supaya", "guna", "kah", "pun", "sampai",
                  "sedangkan", "selagi", "sementara", "tetapi", "apakah", "kecuali", "sebab", "selain", "seolah", "seraya",
                  "seterusnya", "tanpa", "agak", "boleh", "dapat", "dsb", "dst", "dll", "dahulu", "dulunya", "anu", "demikian",
                  "tapi", "ingin", "juga", "nggak", "mari", "nanti", "melainkan", "oh", "ok", "seharusnya", "sebetulnya",
                  "setiap", "setidaknya", "sesuatu", "pasti", "saja", "toh", "ya", "walau", "tolong", "tentu", "amat",
                  "apalagi", "bagaimanapun"]

list_stopwords = stopwords.words("indonesian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ekapr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Mendeklarasikan fungsi untuk list_stopwords untuk Bahasa Indonesia
def list_stopwords_text(text):
    return [word for word in text if word not in list_stopwords]

data_hepatitis["Tweet Stopwords"] = data_hepatitis["Tweet Tokenizing"].apply(list_stopwords_text)

# %%
"""
Mendeklarasikan fungsi untuk untuk menghapus kata-kata yang ada 
di dalam list (list_delete). List_delete menampung kata-kata imbuhan yang telah didefisinikan
untuk dihapus dari daftar teks dan menampilkan data sebanyak 8 data terbawah
"""
def stopwords_text(text):
    return [word for word in text if word not in remove_affixes]

data_hepatitis["Tweet Stopwords"] = data_hepatitis["Tweet Stopwords"].apply(stopwords_text)
data_hepatitis.tail(8)
# Out:
#              Waktu Tweet          Username  \
# 891  2022-06-17 02:16:51  ujang frusciante
# 892  2022-06-17 02:14:14         hermionne
# 893  2022-06-17 02:12:54     anisa cenceni
# 894  2022-06-17 02:12:14          suparman
# 895  2022-06-17 02:09:13        snow white
# 896  2022-06-17 02:03:05      dindu nuffin
# 897  2022-06-17 02:00:00      duah menaria
# 898  2022-06-17 01:45:06           sunday
#
#                                                  Tweet  Sentimen  \
# 891  ikn sejahterakan negeri waspada informasi hoax...   Neutral
# 892  ikn sejahterakan negeri waspada disinformasi d...   Neutral
# 893   disinformasi vaksin mrna menyebabkan hepatiti...   Neutral
# 894  tidak benar jika vaksin menyebabkan hepatitis ...  Negative
# 895  vaksin astrazeneca bukan pemicu hepatitis akut...  Positive
# 896  kandungan adenovirus pada vaksin covid bukan p...   Neutral
# 897  vaksin covid anak aman waspada provokasi kelom...  Positive
# 898  sini konten nct datang aja barengan gue gak ta...  Positive
#
#                                     Tweet Case Folding  \
# 891  ikn sejahterakan negeri waspada informasi hoax...
# 892  ikn sejahterakan negeri waspada disinformasi d...
# 893   disinformasi vaksin mrna menyebabkan hepatiti...
# 894  tidak benar jika vaksin menyebabkan hepatitis ...
# 895  vaksin astrazeneca bukan pemicu hepatitis akut...
# 896  kandungan adenovirus pada vaksin covid bukan p...
# 897  vaksin covid anak aman waspada provokasi kelom...
# 898  sini konten nct datang aja barengan gue gak ta...
#
#                                       Tweet Tokenizing  \
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 894  [tidak, benar, jika, vaksin, menyebabkan, hepa...
# 895  [vaksin, astrazeneca, bukan, pemicu, hepatitis...
# 896  [kandungan, adenovirus, pada, vaksin, covid, b...
# 897  [vaksin, covid, anak, aman, waspada, provokasi...
# 898  [sini, konten, nct, datang, aja, barengan, gue...
#
#                                        Tweet Stopwords
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 894  [vaksin, menyebabkan, hepatitis, anak, vaksina...
# 895  [vaksin, astrazeneca, pemicu, hepatitis, akut,...
# 896  [kandungan, adenovirus, vaksin, covid, penyeba...
# 897  [vaksin, covid, anak, aman, waspada, provokasi...
# 898  [konten, nct, aja, barengan, gue, gak, takutt,...

# %% [markdown]
# Tahapan selanjutnya dalam text processing adalah proses normalisasi. Teknik normalisasi merupakan sebuah tahapan kegiatan text preprocessing untuk mengubah kata-kata yang tidak baku atau kata yang ditulis dengan bahasa "gaul" atau bahasa sehari-hari menjadi kata baku.

# %% [markdown]
# ### 3.5. Normalisasi

# %%
"""
Melakukan perubahan kalimat dasar dari bahasa selain bahasa indonesia menjadi
bahasa indonesia yang baku dengan proses normalisasi. Teknik normalisasi merupakan sebuah teknik untuk mengubah
kata-kata "gaul" atau kata-kata yang tidak baku menjadi sebuah kata yang tepat dan menampilkan data sebanyak 19 data terbawah
"""
normalize_words = {"tanyaaa": "tanya",
                   "kenapaa": "kenapa",
                   "suplemenkesehatan": "suplemen kesehatan",
                   "obatherbal": "obat herbal",
                   "cholestrol": "kolesterol",
                   "aware": "peduli",
                   "byeeee": "bye",
                   "magh": "maag",
                   "mmg": "memang",
                   "anak2": "anak-anak",
                   "rilissehat": "rilis sehat",
                   "pelayana": "pelayanan",
                   "gaada": "tidak ada",
                   "atlit2":"atlit-atlit",
                   "kalo": "kalau",
                   "kaitanny": "kaitannya",
                   "sampe": "sampe",
                   "indonesiawaspada": "indonesia waspada",
                   "yaaaa": "ya", 
                   "indonesiawaspada": "indonesia waspada",
                   "antijamur": "anti jamur",
                   "lu": "lu",
                   "bbrp": "beberapa",
                   "lengkapivaksinperketatprokes": "lengkapi vaksin perketat prokes",
                   "antibakteri": "anti bakteri"
                  }

def word_normalization(document):
    return [normalize_words[term] if term in normalize_words else term for term in document]

data_hepatitis["Tweet Normalisasi"] = data_hepatitis["Tweet Stopwords"].apply(word_normalization)
data_hepatitis.tail(19)
# Out:
#              Waktu Tweet           Username  \
# 880  2022-06-17 02:49:29       doli siagian
# 881  2022-06-17 02:48:55          ayam jago
# 882  2022-06-17 02:47:29      nadya rahmaaa
# 883  2022-06-17 02:47:18               erie
# 884  2022-06-17 02:45:22   kelurahan garuda
# 885  2022-06-17 02:42:00       lalalanina55
# 886  2022-06-17 02:41:45   narasi indonesia
# 887  2022-06-17 02:30:37  humas polreslahat
# 888  2022-06-17 02:25:25         amoi kurau
# 889  2022-06-17 02:20:10        elina azkia
# 890  2022-06-17 02:19:20       askadi pijay
# 891  2022-06-17 02:16:51   ujang frusciante
# 892  2022-06-17 02:14:14          hermionne
# 893  2022-06-17 02:12:54      anisa cenceni
# 894  2022-06-17 02:12:14           suparman
# 895  2022-06-17 02:09:13         snow white
# 896  2022-06-17 02:03:05       dindu nuffin
# 897  2022-06-17 02:00:00       duah menaria
# 898  2022-06-17 01:45:06            sunday
#
#                                                  Tweet  Sentimen  \
# 880  waspada provokasi kelompok kepentingan yang me...  Positive
# 881   penyebab munculnya hepatitis misterius bukan ...   Neutral
# 882  vaksinasi covid tidak menyebabkan kasus hepati...  Positive
# 883  waspada hoax vaksinasi covid tak terkait denga...  Positive
# 884  giat seklur garuda mengikuti kegiatan sosialis...  Positive
# 885  adenovirus vaksin astrazeneca picu hepatitis a...  Positive
# 886  vaksinasi covid tidak sebabkan hepatitis akut ...  Positive
# 887  maraknya penyakit hepatitis yang menyerang ana...  Positive
# 888  waspada hoax tidak ada korelasi antara hepatit...   Neutral
# 889  awas hoax adenovirus divaksinasi astrazeneca b...  Positive
# 890  ikn sejahterakan negeri jangan percaya hoax va...   Neutral
# 891  ikn sejahterakan negeri waspada informasi hoax...   Neutral
# 892  ikn sejahterakan negeri waspada disinformasi d...   Neutral
# 893   disinformasi vaksin mrna menyebabkan hepatiti...   Neutral
# 894  tidak benar jika vaksin menyebabkan hepatitis ...  Negative
# 895  vaksin astrazeneca bukan pemicu hepatitis akut...  Positive
# 896  kandungan adenovirus pada vaksin covid bukan p...   Neutral
# 897  vaksin covid anak aman waspada provokasi kelom...  Positive
# 898  sini konten nct datang aja barengan gue gak ta...  Positive
#
#                                     Tweet Case Folding  \
# 880  waspada provokasi kelompok kepentingan yang me...
# 881   penyebab munculnya hepatitis misterius bukan ...
# 882  vaksinasi covid tidak menyebabkan kasus hepati...
# 883  waspada hoax vaksinasi covid tak terkait denga...
# 884  giat seklur garuda mengikuti kegiatan sosialis...
# 885  adenovirus vaksin astrazeneca picu hepatitis a...
# 886  vaksinasi covid tidak sebabkan hepatitis akut ...
# 887  maraknya penyakit hepatitis yang menyerang ana...
# 888  waspada hoax tidak ada korelasi antara hepatit...
# 889  awas hoax adenovirus divaksinasi astrazeneca b...
# 890  ikn sejahterakan negeri jangan percaya hoax va...
# 891  ikn sejahterakan negeri waspada informasi hoax...
# 892  ikn sejahterakan negeri waspada disinformasi d...
# 893   disinformasi vaksin mrna menyebabkan hepatiti...
# 894  tidak benar jika vaksin menyebabkan hepatitis ...
# 895  vaksin astrazeneca bukan pemicu hepatitis akut...
# 896  kandungan adenovirus pada vaksin covid bukan p...
# 897  vaksin covid anak aman waspada provokasi kelom...
# 898  sini konten nct datang aja barengan gue gak ta...
#
#                                       Tweet Tokenizing  \
# 880  [waspada, provokasi, kelompok, kepentingan, ya...
# 881  [penyebab, munculnya, hepatitis, misterius, bu...
# 882  [vaksinasi, covid, tidak, menyebabkan, kasus, ...
# 883  [waspada, hoax, vaksinasi, covid, tak, terkait...
# 884  [giat, seklur, garuda, mengikuti, kegiatan, so...
# 885  [adenovirus, vaksin, astrazeneca, picu, hepati...
# 886  [vaksinasi, covid, tidak, sebabkan, hepatitis,...
# 887  [maraknya, penyakit, hepatitis, yang, menyeran...
# 888  [waspada, hoax, tidak, ada, korelasi, antara, ...
# 889  [awas, hoax, adenovirus, divaksinasi, astrazen...
# 890  [ikn, sejahterakan, negeri, jangan, percaya, h...
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 894  [tidak, benar, jika, vaksin, menyebabkan, hepa...
# 895  [vaksin, astrazeneca, bukan, pemicu, hepatitis...
# 896  [kandungan, adenovirus, pada, vaksin, covid, b...
# 897  [vaksin, covid, anak, aman, waspada, provokasi...
# 898  [sini, konten, nct, datang, aja, barengan, gue...
#
#                                        Tweet Stopwords  \
# 880  [waspada, provokasi, kelompok, kepentingan, me...
# 881  [penyebab, munculnya, hepatitis, misterius, va...
# 882  [vaksinasi, covid, menyebabkan, hepatitis, aku...
# 883  [waspada, hoax, vaksinasi, covid, terkait, hep...
# 884  [giat, seklur, garuda, mengikuti, kegiatan, so...
# 885  [adenovirus, vaksin, astrazeneca, picu, hepati...
# 886  [vaksinasi, covid, sebabkan, hepatitis, akut, ...
# 887  [maraknya, penyakit, hepatitis, menyerang, ana...
# 888  [waspada, hoax, korelasi, hepatitis, vaksin, k...
# 889  [awas, hoax, adenovirus, divaksinasi, astrazen...
# 890  [ikn, sejahterakan, negeri, percaya, hoax, vak...
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 894  [vaksin, menyebabkan, hepatitis, anak, vaksina...
# 895  [vaksin, astrazeneca, pemicu, hepatitis, akut,...
# 896  [kandungan, adenovirus, vaksin, covid, penyeba...
# 897  [vaksin, covid, anak, aman, waspada, provokasi...
# 898  [konten, nct, aja, barengan, gue, gak, takutt,...
#
#                                      Tweet Normalisasi
# 880  [waspada, provokasi, kelompok, kepentingan, me...
# 881  [penyebab, munculnya, hepatitis, misterius, va...
# 882  [vaksinasi, covid, menyebabkan, hepatitis, aku...
# 883  [waspada, hoax, vaksinasi, covid, terkait, hep...
# 884  [giat, seklur, garuda, mengikuti, kegiatan, so...
# 885  [adenovirus, vaksin, astrazeneca, picu, hepati...
# 886  [vaksinasi, covid, sebabkan, hepatitis, akut, ...
# 887  [maraknya, penyakit, hepatitis, menyerang, ana...
# 888  [waspada, hoax, korelasi, hepatitis, vaksin, k...
# 889  [awas, hoax, adenovirus, divaksinasi, astrazen...
# 890  [ikn, sejahterakan, negeri, percaya, hoax, vak...
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 894  [vaksin, menyebabkan, hepatitis, anak, vaksina...
# 895  [vaksin, astrazeneca, pemicu, hepatitis, akut,...
# 896  [kandungan, adenovirus, vaksin, covid, penyeba...
# 897  [vaksin, covid, anak, aman, waspada, provokasi...
# 898  [konten, nct, aja, barengan, gue, gak, takutt,...

# %% [markdown]
# Tahapan terakhir dalam text processing adalah proses stemming. Teknik stemming merupakan sebuah tahapan kegiatan text preprocessing untuk membentuk sebuah kata baru dengan menambahkan kata imbuhan terhadap suatu kata yang tidak mengubah kelas kata tersebut. Teknik stemming juga dapat dikatakan sebagai teknik yang mengelompokkan kata-kata lain yang memiliki kata dasar dan arti yang serupa namun memiliki bentuk yang berbeda karena mendapatkan imbuhan yang berbeda pula.

# %% [markdown]
# ### 3.6. Stemming

# %%
# Proses Stemming dibantu dengan bantuan swifter
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# Membuat Stemmer dari sastrawi
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Membuat fungsi stemming
def stemming(text):
    return stemmer.stem(text)

term_dict = {}

# Menghitung ada berapa kata/words di dalam kolom "Tweet Normalisasi"
for document in data_hepatitis["Tweet Normalisasi"]:
    for text in document:
        if text not in term_dict:
            term_dict[text] = " "
            
print(len(term_dict))
print("------------------------")

# Menampilkan isi kata/words yang telah dilakukan proses stemming
for text in term_dict:
    term_dict[text] = stemming(text)
    print(text,":" ,term_dict[text])
    
print(term_dict)
print("------------------------")

# Membuat fungsi baru untuk proses stemming
def stemming_words(document):
    return [term_dict[text] for text in document]

data_hepatitis["Tweet Stemming"] = data_hepatitis["Tweet Normalisasi"].swifter.apply(stemming_words)
# Out:
# 2136
# ------------------------
# dok : dok
# tanya : tanya
# kalau : kalau
# tes : tes
# hepatitis : hepatitis
# sgot : sgot
# sgpt : sgpt
# ningkat : ningkat
# kenapa : kenapa
# terbaik : baik
# teraman : ram
# supplement : supplement
# kesehatan : sehat
# kapsul : kapsul
# spirulina : spirulina
# kolesterol : kolesterol
# diabetes : diabetes
# jantung : jantung
# kapsulspirulina : kapsulspirulina
# herbalspirulina : herbalspirulina
# obat herbal : obat herbal
# suplemen kesehatan : suplemen sehat
# ketua : ketua
# dpr : dpr
# puan : puan
# maharani : maharani
# menyoroti : sorot
# perhatian : perhati
# khusus : khusus
# sidang : sidang
# kali : kali
# akut : akut
# anak : anak
# masyarakat : masyarakat
# membuktikan : bukti
# betapa : betapa
# pedulinya : peduli
# permasalahan : masalah
# tanah : tanah
# air : air
# harga : harga
# pangan : pangan
# lebaran : lebaran
# pemulihan : pulih
# ekonomi : ekonomi
# pandemi : pandemi
# covid : covid
# mereda : reda
# ambil : ambil
# ujian : uji
# darah : darah
# doktor : doktor
# cantik : cantik
# okay : okay
# hiv : hiv
# negative : negative
# lepas : lepas
# nak : nak
# cari : cari
# duit : duit
# extra : extra
# jual : jual
# vaksin : vaksin
# gak : gak
# salah : salah
# misterius : misterius
# rakyatmelawanmandatory : rakyatmelawanmandatory
# who : who
# laporkan : lapor
# 920 : 920
# tersebar : sebar
# negara : negara
# klik : klik
# baca : baca
# ramai : ramai
# penyebabnya : sebab
# biar : biar
# peduli : peduli
# gejala : gejala
# penyakit : sakit
# yuk : yuk
# tonton : tonton
# penjelasan : jelas
# lengkap : lengkap
# prof : prof
# hinky : hinky
# hindra : hindra
# irawan : irawan
# satari : satar
# troppaed : troppaed
# video : video
# mulan : mulan
# gunung : gunung
# bye : bye
# gue : gue
# udah : udah
# stres : stres
# minggu : minggu
# kertas : kertas
# jahanam : jahanam
# selamat : selamat
# tinggal : tinggal
# blok : blok
# gastrointestinal : gastrointestinal
# lambung : lambung
# teman : teman
# temannya : teman
# bahas : bahas
# maag : maag
# gerd : gerd
# malnutrisi : malnutrisi
# hemoroid : hemoroid
# appendisitis : appendisitis
# peritonitis : peritonitis
# gila : gila
# memang : memang
# anak-anak : anak
# kena : kena
# orang : orang
# tua : tua
# mudah : mudah
# sakit : sakit
# rilis sehat : rilis sehat
# patogen : patogen
# ditemukan : temu
# pasien : pasien
# perawatan : awat
# kecantikan : cantik
# dibahas : bahas
# jarang : jarang
# kesehatannya : sehat
# pastikan : pasti
# hpv : hpv
# tetanus : tetanus
# cek : cek
# ims : ims
# pre : pre
# marital : marital
# medical : medical
# check : check
# genjot : genjot
# vaksinasi : vaksinasi
# booster : booster
# binda : binda
# jateng : jateng
# menyebabkan : sebab
# terkait : kait
# 100 : 100
# aman : aman
# peringatkan : ingat
# meningkat : tingkat
# kenali : kenal
# gejalanya : gejala
# mengintai : intai
# bunda : bunda
# pencegahannya : cegah
# benarkan : benar
# adenovirus : adenovirus
# astrazeneca : astrazeneca
# picu : picu
# dokter : dokter
# penyebab : sebab
# herbal : herbal
# medan : medan
# bpom : bpom
# mui : mui
# syariah : syariah
# admin : admin
# pin : pin
# 545481bb : 545481bb
# call : call
# 081269806871 : 081269806871
# pancasila : pancasila
# satukan : satu
# negeri : negeri
# normalisasi : normalisasi
# alkoholik : alkoholik
# biarkan : biar
# kalangan : kalang
# muslim : muslim
# terserah : serah
# agama : agama
# non : non
# islam : islam
# mabok : mabok
# sampe : sampe
# kanker : kanker
# hati : hati
# promokan : promokan
# tutupholywingsindonesia : tutupholywingsindonesia
# gakk : gakk
# ahh : ahh
# ntr : ntr
# terbukti : bukti
# mrna : mrna
# rumah : rumah
# nya : nya
# kosong : kosong
# dikejar : kejar
# aja : aja
# senin : senin
# pas : pas
# bayi : bayi
# anaknya : anak
# jalur : jalur
# pribadi : pribadi
# iya : iya
# coba : coba
# gimana : gimana
# munculnya : muncul
# kejadian : jadi
# kaitannya : kait
# astrazaneca : astrazaneca
# faktanya : fakta
# simak : simak
# penjelasannya : jelas
# sebabkan : sebab
# hubungan : hubung
# bermanfaat : manfaat
# padabvaksin : padabvaksin
# asteazeneca : asteazeneca
# hebat : hebat
# mantap : mantap
# oke : oke
# putus : putus
# penularan : tular
# spilis : spil
# warga : warga
# binaan : bina
# lapas : lapas
# leok : leok
# laksanakan : laksana
# pemeriksaan : periksa
# selengkapnya : lengkap
# kemenkumhamri : kemenkumhamri
# stop : stop
# panik : panik
# astrazenca : astrazenca
# hubungannya : hubung
# aneh : aneh
# menghubungkan : hubung
# probable : probable
# indonesia : indonesia
# adenoviros : adenoviros
# berasal : asal
# lawan : lawan
# hoax : hoax
# ges : ges
# seputar : putar
# tim : tim
# sehat : sehat
# pemicu : picu
# timbulnya : timbul
# fakta : fakta
# berdasar : dasar
# waspadaaa : waspadaaa
# moderna : moderna
# dgn : dgn
# waspada : waspada
# biasakan : biasa
# hidup : hidup
# bersih : bersih
# disiplinprokestangkalomicron : disiplinprokestangkalomicron
# kandungan : kandung
# berkaitan : kait
# teruji : uji
# amp : amp
# terjamin : jamin
# sertifikasi : sertifikasi
# kaitan : kait
# negri : negri
# covid19 : covid19
# percaya : percaya
# astra : astra
# vaksina : vaksina
# disebabkan : sebab
# kementerian : menteri
# kemenkes : kemenkes
# dugaan : duga
# berhasil : hasil
# kumparannews : kumparannews
# andenovirus : andenovirus
# aztrazeneca : aztrazeneca
# hmmm : hmmm
# mah : mah
# masuk : masuk
# indikasi : indikasi
# gugurkan : gugur
# sih : sih
# nder : nder
# indo : indo
# make : make
# sure : sure
# nnati : nnati
# periksa : periksa
# hamil : hamil
# triple : triple
# elimination : elimination
# aids : aids
# sifilis : sifilis
# wajib : wajib
# kasian : kasi
# calon : calon
# alhamdulilah : alhamdulilah
# sekaliny : sekaliny
# drawat : drawat
# tumor : tumor
# paha : paha
# 2010 : 2010
# 2015 : 2015
# 2019 : 2019
# msh : msh
# observasi : observasi
# ttp : ttp
# dirawat : rawat
# 2022 : 2022
# guaa : guaa
# jugaa : jugaa
# ngerasain : ngerasain
# ekpetasi : ekpetasi
# gua : gua
# cacar : cacar
# monyet : monyet
# engga : engga
# yaa : yaa
# kurikulum : kurikulum
# merdeka : merdeka
# lahh : lahh
# inii : ini
# wadidawwww : wadidawwww
# penemuan : temu
# terapi : terapi
# efektik : efektik
# terjangkau : jangkau
# virus : virus
# influenza : influenza
# rabies : rabies
# perusahaan : usaha
# menjanjikan : janji
# adakah : ada
# bukti : bukti
# valid : valid
# penelitian : teliti
# con : con
# asjadmakdlqkwjqk : asjadmakdlqkwjqk
# ngew : ngew
# cowonya : cowonya
# sertakan : serta
# ktp : ktp
# hasil : hasil
# pcr : pcr
# kecoa : kecoa
# coro : coro
# sebelas : sebelas
# belas : belas
# lalat : lalat
# agen : agen
# sumber : sumber
# alergen : alergen
# serangan : serang
# asma : asma
# membawa : bawa
# poliomyelitis : poliomyelitis
# catat : catat
# 650 : 650
# ilmuwan : ilmuwan
# teori : teori
# provinsi : provinsi
# disumbangkan : sumbang
# diuji : uji
# menular : tular
# ditransfusi : transfusi
# 900 : 900
# fokusutama : fokusutama
# nasional : nasional
# herpes : herpes
# simplex : simplex
# encephalitis : encephalitis
# gastritis : gastritis
# meningitis : meningitis
# meningoencephalitis : meningoencephalitis
# meningomyelitis : meningomyelitis
# necrotising : necrotising
# retinopathy : retinopathy
# oesophagitis : oesophagitis
# otitis : otitis
# externa : externa
# pharyngitis : pharyngitis
# pneumonia : pneumonia
# dilaporkan : lapor
# anakanak : anakanak
# melaporkan : lapor
# total : total
# melonjak : lonjak
# kabar : kabar
# cmv : cmv
# inersia : inersia
# patogencmv : patogencmv
# biang : biang
# kerok : kerok
# dunia : dunia
# hepatitisakut : hepatitisakut
# bupati : bupati
# deli : deli
# serdang : serdang
# diwakili : wakil
# asisten : asisten
# pemerintah : perintah
# kesejahteraan : sejahtera
# rakyat : rakyat
# drs : drs
# citra : citra
# effendy : effendy
# capah : capah
# msp : msp
# membuka : buka
# seminar : seminar
# workshop : workshop
# penatalaksanaan : penatalaksanaan
# long : long
# syndrom : syndrom
# wing : wing
# hotel : hotel
# kualanamu : kualanamu
# sabtu : sabtu
# batalyon : batalyon
# armed : armed
# 105 : 105
# biringgalih : biringgalih
# melaksanakan : laksana
# kegiatan : giat
# aula : aula
# tujuan : tuju
# menjaga : jaga
# stamina : stamina
# prajurit : prajurit
# mencegah : cegah
# lingkungan : lingkung
# tni : tni
# jumat : jumat
# temukan : temu
# persen : persen
# divaksin : vaksin
# mayoritas : mayoritas
# usia : usia
# balita : balita
# insfrastruktur : insfrastruktur
# nusantara : nusantara
# infrastruktur : infrastruktur
# uji : uji
# metode : metode
# bingung : bingung
# kontrol : kontrol
# positif : positif
# papers : papers
# pakai : pakai
# dna : dna
# sintetik : sintetik
# mahillll : mahillll
# beberkan : kan
# rinciannya : rinciannya
# muncul : muncul
# ayo : ayo
# termakan : makan
# hoaks : hoaks
# mengebabkan : kebab
# memicu : picu
# beredar : edar
# unggahan : unggah
# mengakibatkan : akibat
# wapada : wapada
# hubuangannya : hubuangannya
# berpendapat : dapat
# denga : denga
# provokasi : provokasi
# kelompok : kelompok
# kepentingan : penting
# mengaitkan : kait
# membantah : ban
# kaitanya : kaitanya
# tempotekno : tempotekno
# dampat : dampat
# terprovokasi : provokasi
# berita : berita
# mata : mata
# turun : turun
# namanya : nama
# pengaruh : pengaruh
# leres : les
# teu : teu
# aya : aya
# nyababkeun : nyababkeun
# patitis : patitis
# geneva : geneva
# kes : kes
# berkemungkinan : mungkin
# teruk : teruk
# kanak : kanak
# setakat : takat
# bener : bener
# ora : ora
# ana : ana
# sing : sing
# nyebabake : nyebabake
# cerdas : cerdas
# menanggapi : tanggap
# isu : isu
# true : true
# there : there
# vaccine : vaccine
# that : that
# causes : causes
# bohong : bohong
# zaneka : zaneka
# korelasi : korelasi
# eropa : eropa
# menyumbang : sumbang
# 267 : 267
# inggris : inggris
# jabar : jabar
# wabah : wabah
# menulari : tular
# ratusan : ratus
# sayangnya : sayang
# akun : akun
# media : media
# sosial : sosial
# memuat : muat
# klaim : klaim
# menuduh : tuduh
# diduga : duga
# pemicunya : picu
# diimbau : imbau
# jaga : jaga
# siasatan : siasat
# kajian : kaji
# jawapan : jawapan
# punca : punca
# berlaku : laku
# asbab : asbab
# peningkatan : tingkat
# kanak2 : kanak2
# kumulatif : kumulatif
# juni : juni
# bhdunia : bhdunia
# dikesan : kes
# menghidap : menghidap
# pemindahan : pindah
# kematian : mati
# tdk : tdk
# dilabeli : label
# scr : scr
# scientific : scientific
# hipotesis : hipotesis
# krn : krn
# concluded : concluded
# thn : thn
# favorit : favorit
# netizen : netizen
# pdhal : pdhal
# bertambah : tambah
# keradangan : radang
# pencegahan : cegah
# jom : jom
# tipskesihatan : tipskesihatan
# testimoni : testimoni
# benjolan : benjol
# leher : leher
# prematur : prematur
# nicu : nicu
# sembuh : sembuh
# fatty : fatty
# liver : liver
# kista : kista
# autoimun : autoimun
# mengecil : kecil
# konsumsi : konsumsi
# suba : suba
# utsu : utsu
# afc : afc
# makasih : makasih
# infonya : info
# semoga : moga
# berkah : berkah
# hidupnya : hidup
# belang : belang
# akhir2 : akhir2
# sentiasa : sentiasa
# pergaulan : gaul
# kebersihan : bersih
# kawasaki : kawasaki
# hfmd : hfmd
# rsv : rsv
# elak : elak
# jangkitan : jangkit
# vaspada : vaspada
# informasi : informasi
# dinyatakan : nyata
# tetangga : tetangga
# sebulan : bulan
# yll : yll
# perempuan : perempuan
# yatim : yatim
# piatu : piatu
# diagnosa : diagnosa
# dengue : dengue
# syndrome : syndrome
# kondisi : kondisi
# memburuk : buruk
# tetiba : tetiba
# pulang : pulang
# dapet : dapet
# meninggal : tinggal
# rsud : rsud
# depati : depati
# hamzah : hamzah
# gratis : gratis
# jakarta : jakarta
# lengkapcepatberitanya : lengkapcepatberitanya
# beritaterkini : beritaterkini
# news : news
# beritanasional : beritanasional
# itb177 : itb177
# medicines : medicines
# homa : homa
# huwa : huwa
# inasababishwa : inasababishwa
# wakati : wakati
# mwengine : mwengine
# ambavyo : ambavyo
# vya : vya
# vinaishig : vinaishig
# kwenye : kwenye
# damu : damu
# maji : maji
# mwili : mwili
# kama : kama
# vile : vile
# usipovaa : usipovaa
# ndomu : ndomu
# unaweza : unaweza
# ukaambukizwa : ukaambukizwa
# meist : meist
# maria : maria
# andre : andre
# taulany : taulany
# tiara : tiara
# andini : andini
# kapolsek : kapolsek
# pedulilindungi : pedulilindungi
# widi : widi
# iwan : iwan
# fals : fals
# israel : israel
# raffi : raffi
# ahmad : ahmad
# yuki : yuk
# rizky : rizky
# febian : febian
# italy : italy
# polygon : polygon
# smpn : smpn
# tercatat : catat
# syahril : syahril
# laki : laki
# bleeding : bleeding
# hepatitismisterius : hepatitismisterius
# kondisinya : kondisi
# update : update
# pending : pending
# discarded : discarded
# sblm : sblm
# hire : hire
# nanny : nanny
# mending : mending
# psikologi : psikologi
# sosmednya : sosmednya
# zonk : zonk
# kayak : kayak
# gini : gin
# nantikan : nanti
# menarik : tarik
# vasksinasi : vasksinasi
# link : link
# evaluasi : evaluasi
# program : program
# kerja : kerja
# narahubung : narahubung
# caca : caca
# line : line
# rizchanf12 : rizchanf12
# mitos : mitos
# nutrilicious : nutrilicious
# efek : efek
# samping : samping
# parah : parah
# kebenaran : benar
# informasinya : informasi
# infografis : infografis
# paham : paham
# hello : hello
# pawrents : pawrents
# doa : doa
# kucingku : kucing
# mohon : mohon
# doanya : doa
# bermain : main
# makasii : makasii
# info : info
# manfaat : manfaat
# donor : donor
# pendonor : donor
# memperoleh : oleh
# rutin : rutin
# menyumbangkan : sumbang
# meliputi : liput
# kadar : kadar
# tekanan : tekan
# tertular : tular
# infeksi : infeksi
# dalang : dalang
# gasalah : gasalah
# tuh : tuh
# imunisasi : imunisasi
# nikah : nikah
# lab : lab
# kaya : kaya
# sivilis : sivilis
# gitu : gitu
# cmiiw : cmiiw
# complexion : complexion
# purbasari : purbasari
# membuatku : buat
# dialami : alami
# mencatat : catat
# cytomegalovirus : cytomegalovirus
# kamis : kamis
# rincian : rincian
# terungkap : ungkap
# hasilnya : hasil
# juru : juru
# bicara : bicara
# mohammad : mohammad
# buka : buka
# suara : suara
# akus : akus
# okezone : okezone
# opsiin : opsiin
# google : google
# terbaru : baru
# hollaa : hollaa
# ruang : ruang
# kuliah : kuliah
# kabarnya : kabar
# juli : juli
# ikuti : ikut
# virtual : virtual
# mengenal : kenal
# misterisus : misterisus
# narasumber : narasumber
# moderator : moderator
# super : super
# kece : kece
# patner : patner
# penyumbang : sumbang
# celebrities : celebrities
# menerbitkan : terbit
# surat : surat
# edaran : edar
# kewaspadaan : waspada
# etiologinya : etiologi
# investigasi : investigasi
# suspek : suspek
# berstatus : status
# status : status
# classification : classification
# lakukan : laku
# dick : dick
# lahiran : lahir
# normal : normal
# lifestyle : lifestyle
# jalani : jalan
# perawat : awat
# makassar : makassar
# membunuh : bunuh
# dibandingkan : banding
# malaria : malaria
# tbc : tbc
# blogpost : blogpost
# infokesehatan : infokesehatan
# dinas : dinas
# kota : kota
# puskemas : puskemas
# ikn : ikn
# majukan : maju
# akibat : akibat
# live : live
# penanganan : tangan
# menyebakan : seba
# era : era
# tirani : tirani
# medis : medis
# cabal : cabal
# big : big
# pharma : pharma
# misteri2 : misteri2
# stroke : stroke
# berhenti : henti
# abg : abg
# tiba2 : tiba2
# mati : mati
# terduga : duga
# tidurnya : tidur
# misteri : misteri
# atlit-atlit : atlit-atlit
# sma : sma
# jatuh : jatuh
# main : main
# bola : bola
# lumpuh : lumpuh
# muke : muke
# kebutaan : buta
# ttg : ttg
# beban : beban
# ganda : ganda
# overworked : overworked
# berujung : ujung
# serius : serius
# kelenjer : kelenjer
# getah : getah
# bening : bening
# cancer : cancer
# sadar : sadar
# nonton : nonton
# liberation : liberation
# notes : notes
# scene : scene
# ibunya : ibu
# jeong : jeong
# kesannya : kesan
# kut : kut
# hai : hai
# healthies : healthies
# maraknya : marak
# rangka : rangka
# menyambut : sambut
# sedunia : dunia
# tanggal : tanggal
# dki : dki
# bekerjasama : bekerjasama
# cwb : cwb
# mengadakan : ada
# webinar : webinar
# berta : berta
# yowes : yowes
# menyerang : serang
# merebaknya : rebak
# silent : silent
# killer : killer
# diwaspadai : waspada
# pengidap : idap
# terinfeksi : infeksi
# terkai : terka
# indonesia waspada : indonesia waspada
# awas : awas
# kucing : kucing
# waspadai : waspada
# direkomendasikan : rekomendasi
# kronis : kronis
# ahli : ahli
# disebakan : seba
# menyikapi : sikap
# lengkapi vaksin perketat prokes : lengkap vaksin ketat prokes
# planetsejajar : planetsejajar
# farah : farah
# delah : delah
# market : market
# development : development
# director : director
# mhtc : mhtc
# sat : sat
# down : down
# with : with
# briansyah : briansyah
# dewandri : dewandri
# tvri : tvri
# jatim : jatim
# channel : channel
# 23rd : 23rd
# june : june
# share : share
# malaysia : malaysia
# the : the
# treatment : treatment
# hub : hub
# asia : asia
# nyaman : nyaman
# bangkitkan : bangkit
# ungahan : ungahan
# penyebaran : sebar
# kotoran : kotor
# tarakan : tara
# kaltara : kaltara
# infokaltara : infokaltara
# beritakaltara : beritakaltara
# korankaltara : korankaltara
# halal : halal
# ilmiah : ilmiah
# bhwa : bhwa
# jgn : jgn
# ragu : ragu
# berkembang : kembang
# mewaspadai : waspada
# kak : kak
# keterkaitan : kait
# hanifah : hanifah
# oswari : oswari
# lead : lead
# scientist : scientist
# diatas : atas
# memahaminya : paham
# kuatir : kuatir
# dijamin : jamin
# krna : krna
# klinis : klinis
# infanteri : infanteri
# mekanis : mekanis
# 202 : 202
# tajimalela : tajimalela
# polkes : polkes
# bekasi : bekas
# menyelenggarakan : selenggara
# peleton : peleton
# rawa : rawa
# lumbu : lumbu
# tniadmengabdidanmembangunbersamarakyat : tniadmengabdidanmembangunbersamarakyat
# epidemiology : epidemiology
# investigator : investigator
# surveillance : surveillance
# columbus : columbus
# epijobs : epijobs
# sudden : sudden
# adult : adult
# death : death
# idi : idi
# isinya : isi
# profesor : profesor
# sesungguhnya : sungguh
# tutup : tutup
# mulut : mulut
# bini : bini
# mengklaim : klaim
# kesakitan : sakit
# frustrasi : frustrasi
# felderhof : felderhof
# dilain : lain
# guzman : guzman
# dibunuh : bunuh
# freeport : freeport
# bob : bob
# hasan : hasan
# gajelas : gajelas
# repot : repot
# test : test
# kontaknya : kontak
# trs : trs
# gatau : gatau
# konsul : konsul
# ngga : ngga
# kontak : kontak
# dinkes : dinkes
# gencar : gencar
# sosialisasikan : sosialisasi
# bahaya : bahaya
# ajakin : ajakin
# senior : senior
# cuman : cuman
# sayang : sayang
# riwayat : riwayat
# ortu : ortu
# alhamdullilah : alhamdullilah
# ayah : ayah
# terselamatkan : selamat
# mcu : mcu
# kemaren : kemaren
# reaktif : reaktif
# banget : banget
# abis : abis
# sakitan : sakit
# dusun : dusun
# bgt : bgt
# dpt : dpt
# hib : hib
# ipv : ipv
# campak : campak
# nek : nek
# wes : wes
# keno : keno
# koe : koe
# biso : biso
# nge : nge
# tweet : tweet
# ngene : ngene
# meneh : teh
# wibungitis : wibungitis
# jenis : jenis
# goblog : goblog
# wkwk : wkwk
# amit : amit
# measles : measles
# mandi : mandi
# dlu : dlu
# trus : trus
# bersih2 : bersih2
# deh : deh
# tangan : tangan
# mainin : mainin
# titit : titit
# tiati : tiati
# wkk : wkk
# lumayan : lumayan
# mudahan : mudah
# penyerahan : serah
# btw : btw
# terdiagnosa : terdiagnosa
# otomatis : otomatis
# peran : peran
# edukasi : edukasi
# karna : karna
# tau : tau
# kedepannya : depan
# terjangkit : jangkit
# tubuh : tubuh
# merespon : merespon
# ari : ari
# baskoro : baskoro
# spesialis : spesialis
# okdokjtv : okdokjtv
# tayang : tayang
# wib : wib
# kembaliketivi : kembaliketivi
# g20 : g20
# kuat : kuat
# iyah : iyah
# nih : nih
# pakar : pakar
# jelasin : jelasin
# klo : klo
# ama : ama
# lak : lak
# kuning : kuning
# jus : jus
# alpukat : alpukat
# mbak : mbak
# campur : campur
# gula : gula
# susu : susu
# infony : infony
# utk : utk
# dikenali : nali
# disakiti : sakit
# beda : beda
# urusan : urus
# khawatirkan : khawatir
# hadapi : hadap
# berpengaruh : pengaruh
# dengna : dengna
# terpancing : pancing
# berhubungan : hubung
# prokes : prokes
# politik : politik
# identitas : identitas
# ygy : ygy
# berdasarkan : dasar
# penelusuran : telusur
# mengutip : kutip
# laman : laman
# resmi : resmi
# kebanyakan : banyak
# asumsi : asumsi
# terpatahkan : patah
# virusnya : virus
# itupun : itu
# langsung : langsung
# bersamaan : sama
# pastinya : pasti
# pemberian : beri
# menginvestigasi : investigasi
# disinformasi : disinformasi
# waspadaomicronba4ba5 : waspadaomicronba4ba5
# desawisatanusantara : desawisatanusantara
# ketahui : tahu
# cvd : cvd
# kemunculan : muncul
# corona : corona
# dibenarkan : benar
# rscm : rscm
# menerima : terima
# hada : hada
# karin : karin
# bayani : bayan
# game : game
# ciwon : ciwon
# jean : jean
# angka : angka
# huruf : huruf
# hur : hur
# propaganda : propaganda
# menyebarkan : sebar
# gmn : gmn
# emosi : emosi
# bacanya : baca
# tellonym : tellonym
# bgst : bgst
# bocah : bocah
# kerasanya : rasa
# khawatir : khawatir
# cdc : cdc
# mengungkap : ungkap
# jenenge : jenenge
# macem2 : macem2
# ono : ono
# seng : seng
# kikuk : kikuk
# diarani : diarani
# ngelus2 : ngelus2
# lek : lek
# kene : kene
# nang : nang
# member : member
# njaluk : njaluk
# dungo : dungo
# gawe : gawe
# koncone : koncone
# kenek : kenek
# ambek : ambek
# tulang : tulang
# bekas : bekas
# infus : infus
# darahnya : darah
# lengan : lengan
# pegel : gel
# berjam2 : berjam2
# kelar2 : kelar2
# olok2 : olok2
# untung : untung
# pengelola : kelola
# bandara : bandara
# peyakit : peyakit
# hilang : hilang
# kataya : kataya
# kekebalan : kebal
# eehhh : eehhh
# taunya : tau
# paksin : paksin
# gatal2 : gatal2
# ngecek : ngecek
# hbsag : hbsag
# lupa : lupa
# mulu : mulu
# nama : nama
# takut : takut
# lagii : lagi
# polio : polio
# bang : bang
# reihan : reihan
# sekretaris : sekretaris
# jenderal : jenderal
# ilmagi : ilmagi
# membahas : bahas
# tuntas : tuntas
# ketinggalan : tinggal
# upaya : upaya
# mencegahnya : cegah
# april : april
# intensif : intensif
# rsupn : rsupn
# cipto : cipto
# mangunkusumo : mangunkusumo
# raya : raya
# amerika : amerika
# menetapkan : tetap
# klb : klb
# selesai : selesai
# perjuangan : juang
# menghadapi : hadap
# dihadapkan : hadap
# mekanisme : mekanisme
# patofisiologi : patofisiologi
# himpunan : himpun
# mahasiswa : mahasiswa
# gizi : gizi
# upn : upn
# veteran : veteran
# proudly : proudly
# present : present
# pokas : pokas
# podcast : podcast
# kastrad : kastrad
# besok : besok
# phi : phi
# hatinya : hati
# faktcek : faktcek
# antisipasi : antisipasi
# terburuk : buruk
# bentuk : bentuk
# satgas : satgas
# ewa : ewa
# ewe : ewe
# enak : enak
# liat : liat
# ngeri : ngeri
# cuy : cuy
# hola : hola
# ners : ners
# adikku : adik
# sdh : sdh
# dibawa : bawa
# pke : pke
# skincare : skincare
# jdi : jdi
# kusam : kusam
# tar : tar
# oral : oral
# sex : sex
# nihh : nihh
# mensie : mensie
# kasih : kasih
# beresiko : resiko
# gonore : gonore
# klamidia : klamidia
# shigellosis : shigellosis
# kutu : kutu
# kemaluan : malu
# stay : stay
# safe : safe
# pengobatan : obat
# alternatif : alternatif
# bilang : bilang
# moots : moots
# twt : twt
# doakan : doa
# adik : adik
# cepat : cepat
# beraktifitas : beraktifitas
# biasannya : bias
# terimakasih : terimakasih
# satupun : satu
# sebebkan : sebebkan
# gabungkan : gabung
# perburukan : buru
# berat : berat
# tidk : tidk
# hubungnnya : hubungnnya
# bpk : bpk
# lurah : lurah
# menghadiri : hadir
# pertemuan : temu
# pkk : pkk
# kelurahan : lurah
# dumguscariang : dumguscariang
# diisi : isi
# sosialisasi : sosialisasi
# penanggulangan : tanggulang
# kepala : kepala
# uptd : uptd
# puskesmas : puskesmas
# garuda : garuda
# bertempat : tempat
# rabu : rabu
# peneliti : teliti
# nyatakan : nyata
# kunyit : kunyit
# mengatasi : atas
# gangguan : ganggu
# pencernaan : cerna
# melindungi : lindung
# dimanfaatkan : manfaat
# arthritis : arthritis
# menurunkan : turun
# anti bakteri : anti bakteri
# anti jamur : anti jamur
# dumasar : dumasar
# kana : kana
# panilitian : panilitian
# henteu : henteu
# tiasa : tiasa
# adhedhasar : adhedhasar
# riset : riset
# celana : celana
# ganti : ganti
# deredet : deredet
# beli : beli
# immo : immo
# kesalahan : salah
# based : based
# research : research
# can : can
# not : not
# trigger : trigger
# acute : acute
# serious : serious
# question : question
# derma : derma
# doctor : doctor
# cakap : cakap
# amik : amik
# sample : sample
# and : and
# cik : cik
# mesej : mesej
# dalm : dalm
# maksudnya : maksud
# checking : checking
# ngekos : ngekos
# kaka : kaka
# uang : uang
# pnya : pnya
# 20rb : 20rb
# 10rb : 10rb
# ongkos : ongkos
# sklh : sklh
# untk : untk
# makan : makan
# berdua : dua
# sekolah : sekolah
# ayam : ayam
# kulit : kulit
# usus : usus
# berbulan2 : berbulan2
# wkwkw : wkwkw
# menurutnya : turut
# sanggat : sanggat
# mustahil : mustahil
# memeliki : lik
# waspadacovidlengkapivaksin : waspadacovidlengkapivaksin
# menimbulkan : timbul
# omicron : omicron
# disiplin : disiplin
# lengkapi : lengkap
# akuut : akuut
# menjangkit : jangkit
# mengkaitkan : kait
# cvd19 : cvd19
# loh : loh
# merekomendasikan : rekomendasi
# now : now
# hiring : hiring
# std : std
# viral : viral
# data : data
# manager : manager
# kencing : kencing
# unta : unta
# membntu : membntu
# menyembuhkan : sembuh
# pnyakit : pnyakit
# universitas : universitas
# ummul : ummul
# qura : qura
# mekkah : mek
# suka : suka
# sumen : sumen
# hulk : hulk
# warna : warna
# suntikan : sunti
# hep : hep
# org : org
# infection : infection
# langkah : langkah
# ptm : ptm
# perilaku : perilaku
# gaya : gaya
# manusia : manusia
# cntohnya : cntohnya
# mellitus : mellitus
# hipertensi : hipertensi
# sdgkn : sdgkn
# bakteri : bakteri
# btul : btul
# gkk : gkk
# timbul : timbul
# kelenjar : kelenjar
# bkn : bkn
# bawaan : bawa
# orok : orok
# keluhan : keluh
# ringan : ringan
# pusing : pusing
# tanda2 : tanda2
# malam : malam
# min : min
# prodia : prodia
# dewasa : dewasa
# paket : paket
# terkaid : terkaid
# dirgahayu : dirgahayu
# hut61 : hut61
# jokowi : jokowi
# korupsi : korupsi
# roh : roh
# pembahasan : bahas
# postingan : postingan
# aeternum : aeternum
# ekor : ekor
# mematikan : mati
# dibilang : bilang
# unik : unik
# sobat : sobat
# rsi : rsi
# hepatitispadaanak : hepatitispadaanak
# virushepatitis : virushepatitis
# cegahhepatitis : cegahhepatitis
# vaksinhepatitis : vaksinhepatitis
# kamar : kamar
# sabaraha : sabaraha
# sugan : sugan
# personil : personil
# kodim : kodim
# 0507 : 0507
# suntik : suntik
# mengeluarkan : keluar
# statement : statement
# diperhatikan : perhati
# sahabat : sahabat
# inaco : inaco
# serem : rem
# selly : selly
# matanya : mata
# danrem : danrem
# 051 : 051
# wkt : wkt
# brigjen : brigjen
# yustinus : yustinus
# nono : nono
# yulianto : yulianto
# angkatan : angkat
# darat : darat
# bertujuan : tuju
# korem : korem
# terhindar : hindar
# tiyuh : tiyuh
# panaragan : panaragan
# jaya : jaya
# indah : indah
# coronavirus : coronavirus
# lampungpost : lampungpost
# budhi : budhi
# condrowati : condrowati
# imbau : imbau
# pemda : pemda
# dri : dri
# terkena : kena
# pms : pms
# standart : standart
# kondom : kondom
# pengecekan : kece
# berkala : kala
# kesdam : kesdam
# dosis : dosis
# ksa : ksa
# yon : yon
# jln : jln
# narogong : narogong
# kel : kel
# cikiwul : cikiwul
# kec : kec
# bantargebang : bantargebang
# reda : reda
# keluarga : keluarga
# dipersembahkan : sembah
# balai : balai
# laboratorium : laboratorium
# kalibrasi : kalibrasi
# diy : diy
# peradangan : adang
# marak : marak
# pekan : pekan
# berbeda : beda
# maju : maju
# berdampak : dampak
# sisi : sisi
# apapun : apa
# kapasitas : kapasitas
# gerak : gerak
# kabupaten : kabupaten
# pemalang : malang
# membantu : bantu
# meningkatkan : tingkat
# penanggulanan : penanggulanan
# kab : kab
# dibidangi : bidang
# bidang : bidang
# p2p : p2p
# kelas : kelas
# gegara : gegara
# unggulan : unggul
# poin : poin
# rank : rank
# tenang : tenang
# divaksinnya : vaksin
# setahun : tahun
# beh : beh
# nenek : nenek
# gara2 : gara2
# 1944 : 1944
# framingnya : framingnya
# jelek : jelek
# patahin : patahin
# wlopun : wlopun
# dipake : dipake
# nyuci : nyuci
# skt : skt
# pake : pake
# rambut : rambut
# terang : terang
# ya : ya
# basically : basically
# bule : bule
# undertonenya : undertonenya
# cool : cool
# wkwkwkwkwk : wkwkwkwkwk
# jht : jht
# medapat : medapat
# srngan : srngan
# remaja : remaja
# sekarat : sekarat
# dlm : dlm
# tidur : tidur
# atlet : atlet
# berolah : olah
# raga : raga
# kelumpuhan : lumpuh
# wajah : wajah
# solusi : solusi
# tersedia : sedia
# adl : adl
# melanjutkan : lanjut
# perluasan : luas
# aktivitas : aktivitas
# biologis : biologis
# ukraina : ukraina
# 2017 : 2017
# didanai : dana
# dtra : dtra
# black : black
# veatch : veatch
# analisis : analisis
# tularemia : tularemia
# slide : slide
# rusia : rusia
# kesepakatan : sepakat
# pertahanan : tahan
# think : think
# biden : biden
# badan : badan
# pengurangan : kurang
# ancaman : ancam
# defensif : defensif
# rawatan : rawat
# alhamdulillah : alhamdulillah
# aaa : aaa
# gaboleh : gaboleh
# mam : mam
# nasi : nasi
# padang : padang
# perbedaan : beda
# singkat : singkat
# tergantung : gantung
# hanahaki : hanahaki
# disease : disease
# nnya : nnya
# dada : dada
# bulet : bulet
# trmsuk : trmsuk
# online : online
# symposium : symposium
# ikatan : ikat
# tema : tema
# diselenggarakan : selenggara
# terdeteksi : deteksi
# aceh : aceh
# lhokseumawe : lhokseumawe
# bahayanya : bahaya
# swasta : swasta
# nihil : nihil
# allah : allah
# menjurus : jurus
# kutunggu : tunggu
# kuningmu : kuning
# waktuku : waktu
# alias : alias
# ngajak : ngajak
# jalan : jalan
# nyerang : nyerang
# sempurna : sempurna
# rentan : rentan
# terserang : serang
# cemas : cemas
# temanbaikbunda : temanbaikbunda
# panduanbunda : panduanbunda
# ibudananak : ibudananak
# pohon : pohon
# bambu : bambu
# daun : daun
# hijau : hijau
# obat : obat
# pokoknya : pokok
# takutnya : takut
# janin : janin
# narasi : narasi
# dibagikan : bagi
# twitter : twitter
# mei : mei
# tenaga : tenaga
# asing : asing
# kenal : kenal
# sebutan : sebut
# jangka : jangka
# pendek : pendek
# bahaa : bahaa
# varian : varian
# bantu : bantu
# dorong : dorong
# percepatan : cepat
# berbahaya : bahaya
# jahat : jahat
# mbul : mbul
# riaudamai : riaudamai
# ditelusuri : telusur
# disinfomasi : disinfomasi
# monkeypox : monkeypox
# kapitalisme : kapitalisme
# akar : akar
# krisis : krisis
# determinan : determinan
# kebutuhan : butuh
# peradaban : adab
# agung : agung
# fokus : fokus
# pasang : pasang
# tato : tato
# steril : steril
# psg : psg
# tattoo : tattoo
# kredible : kredible
# pastika : pastika
# olahrga : olahrga
# otot : otot
# kenceng : kenceng
# sumpah : sumpah
# kendor : kendor
# batang : batang
# otak : otak
# sarwendah : sarwendah
# dianggap : anggap
# beberapa : beberapa
# pasca : pasca
# vaks : vaks
# masal : masal
# penyakit2 : penyakit2
# mestinya : mesti
# bnykny : bnykny
# para2 : para2
# dktr : dktr
# terpacu : pacu
# unt : unt
# menelitinya : teliti
# dokternya : dokter
# nyinyir : nyinyir
# gelisah : gelisah
# asyik2 : asyik2
# cuek : cuek
# mesti : mesti
# wuooo : wuooo
# 2024 : 2024
# 2034 : 2034
# kunci : kunci
# msih : msih
# pegang : pegang
# siap2 : siap2
# ndowerrr : ndowerrr
# lucu : lucu
# neng : neng
# kuning2 : kuning2
# kek : kek
# muhammad : muhammad
# gambaran : gambar
# chair : chair
# man : man
# pakistan : pakistan
# tahreke : tahreke
# insaf : insaf
# janab : janab
# imran : imran
# khan : khan
# sahab : sahab
# pti : pti
# pori : pori
# qiyadat : qiyadat
# apeel : apeel
# kih : kih
# mere : mere
# walid : walid
# jese : jese
# mozi : mozi
# marz : marz
# mobtala : mobtala
# adana : adana
# rukan : rukan
# hazrat : hazrat
# apel : apel
# madat : madat
# kiya : kiya
# jaye : jaye
# 03009372493 : 03009372493
# porii : pori
# say : say
# mera : mera
# jesii : jesii
# mozii : mozii
# maraz : maraz
# mubtala : mubtala
# adna : adna
# karkun : karkun
# please03009372493 : please03009372493
# cegah : cegah
# bijak : bijak
# mitigasi : mitigasi
# meluasnya : luas
# mengumpulkan : kumpul
# global : global
# publik : publik
# memperkuat : kuat
# deteksi : deteksi
# penyelidikan : lidi
# epidemiologi : epidemiologi
# mencuci : cuci
# sabun : sabun
# memasak : masak
# makanan : makan
# minuman : minum
# matang : matang
# alat : alat
# menghindari : hindar
# memakai : pakai
# masker : masker
# jarak : jarak
# kerumunan : kerumun
# kelelahan : lelah
# mual : mual
# nafsu : nafsu
# menurun : turun
# nyeri : nyeri
# urine : urine
# keruh : keruh
# pernapasan : napas
# feses : feses
# berwarna : warna
# pucat : pucat
# menguning : kuning
# sendi : sendi
# penurunan : turun
# mengalami : alami
# radang : radang
# inflamasi : inflamasi
# respons : respons
# imun : imun
# sars : sars
# cov : cov
# potensi : potensi
# ditimbulkan : timbul
# menanggulanginya : tanggulang
# nahh : nahh
# done : done
# today : today
# makul : makul
# ecommerce : ecommerce
# infrastructure : infrastructure
# startup : startup
# olahraga : olahraga
# konten : konten
# summary : summary
# buku : buku
# chapter : chapter
# organizational : organizational
# behavior : behavior
# culture : culture
# negotiation : negotiation
# hrm : hrm
# model : model
# benefit : benefit
# karyawan : karyawan
# penasaran : penasaran
# kelanjutannya : lanjut
# yaaa : yaaa
# opini : opini
# kiat : kiat
# ciouspedia : ciouspedia
# haloo : haloo
# ciousers : ciousers
# diperbincangkan : bincang
# kejiwaan : jiwa
# psikotes : psikotes
# urin : urin
# tremor : tremor
# buta : buta
# narkoba : narkoba
# dikampusku : kampus
# rontsen : rontsen
# paru : paru
# koas : koas
# dites : tes
# ulang : ulang
# terdampak : dampak
# organ : organ
# tangkalhoaxvaksincovid : tangkalhoaxvaksincovid
# penderita : derita
# terima : terima
# carian : cari
# berpunca : punca
# nusantaraa : nusantaraa
# filosofie : filosofie
# ngenteni : ngenteni
# menciptkan : menciptkan
# dicegah : cegah
# jga : jga
# yagesya : yagesya
# tangkal : tangkal
# emang : emang
# liang : liang
# vagina : vagina
# dlll : dlll
# awam : awam
# sok : sok
# cocotlogi : cocotlogi
# bgini : bgini
# cermin : cermin
# kemajuan : maju
# usaha : usaha
# dasar : dasar
# tuberculosis : tuberculosis
# bcg : bcg
# difteri : difteri
# pertusis : pertusis
# pnuemonia : pnuemonia
# lingkungannya : lingkung
# basmistunting : basmistunting
# terhasut : hasut
# pelajar : ajar
# kemarin : kemarin
# indonesiaopen2022 : indonesiaopen2022
# lgbt : lgbt
# penyuka : suka
# bunuh : bunuh
# mental : mental
# orangnya : orang
# gemulai : gemulai
# terang2an : terang2an
# laki2 : laki2
# efeknya : efek
# buruk : buruk
# sekrg : sekrg
# beredarnya : edar
# awaas : awaas
# sesuai : sesuai
# ktentuan : ktentuan
# dosisi : dosis
# vaksinmu : vaksin
# mens : mens
# lancar : lancar
# obgyn : obgyn
# premarital : premarital
# pricey : pricey
# koinsiden : koinsiden
# risk : risk
# factor : factor
# kebayakanan : kebayakanan
# ciri : ciri
# stumblephobia : stumblephobia
# symptoms : symptoms
# muntah : muntah
# bronkitis : bronkitis
# paleokitis : paleokitis
# maupipis : maupipis
# yanfeimanis : yanfeimanis
# pagi : pagi
# siang : siang
# berangkat : berangkat
# diagnosis : diagnosis
# serang : serang
# via : via
# timbulkan : timbul
# menghantui : hantu
# gigitan : gigit
# hewan : hewan
# penular : tular
# var : var
# jujur : jujur
# nakes : nakes
# disnak : disnak
# iku : iku
# yaowoh : yaowoh
# mbakmami : mbakmami
# pindah : pindah
# jogja : jogja
# vivax : vivax
# rekuren : rekuren
# hajar : hajar
# primakuin : primakuin
# dobel : dobel
# seenggaknya : enggak
# kumat : kumat
# malarianya : malaria
# kopi : kopi
# pulak : pulak
# tiup : tiup
# c19 : c19
# herves : herves
# smua : smua
# gelas : gelas
# hallo : hallo
# rekan : rekan
# mendengar : dengar
# melanda : landa
# detail : detail
# penyakithepatitis : penyakithepatitis
# waspadahepatitis : waspadahepatitis
# bsn : bsn
# namaste : namaste
# sir : sir
# kya : kya
# liye : liye
# paise : paise
# dene : dene
# padte : padte
# rupees : rupees
# primary : primary
# school : school
# camp : camp
# lgakr : lgakr
# lgaya : lgaya
# jata : jata
# registration : registration
# fee : fee
# please : please
# reply : reply
# dimanapun : mana
# salam : salam
# unit : unit
# pkrs : pkrs
# halo : halo
# tautan : taut
# kudus : kudus
# keep : keep
# reminding : rinding
# myself : myself
# bad : bad
# day : day
# shall : shall
# pass : pass
# but : but
# daynya : daynya
# hari2 : hari2
# bahagia : bahagia
# dah : dah
# kenalpasti : kenalpasti
# since : since
# every : every
# end : end
# year : year
# cucuk : cucuk
# too : too
# low : low
# for : for
# age : age
# tula : tula
# penat : penat
# burungmu : burung
# keberadaan : ada
# meresahkan : resah
# gambar : gambar
# morinagachilgo : morinagachilgo
# enakbernutrisi : enakbernutrisi
# saringan : saring
# klinik : klinik
# kesihatan : kesihatan
# kuala : kuala
# lumpur : lumpur
# petang : petang
# risau : risau
# prosedur : prosedur
# sulit : sulit
# marilah : mari
# beramai : ama
# mengonsumsi : konsumsi
# nyambung : nyambung
# gang : gang
# prediksi : prediksi
# 2021 : 2021
# mendadak : dadak
# macam2 : macam2
# sads : sads
# scd : scd
# prediktor : prediktor
# berbasis : bas
# teguh : teguh
# bersandar : sandar
# quran : quran
# meramal : ramal
# tambahn : tambahn
# teratur : atur
# istirahat : istirahat
# lembur : lembur
# nongki : nongki
# stress : stress
# tampi : tampi
# disna : disna
# ekg : ekg
# tensi : tensi
# rotgen : rotgen
# hasilny : hasilny
# bagus : bagus
# knp : knp
# 7kg : 7kg
# scepat : scepat
# you : you
# know : know
# reason : reason
# why : why
# never : never
# story : story
# behind : behind
# jawabannya : jawab
# point : point
# tambahin : tambahin
# itseokjinkim : itseokjinkim
# ganteng : ganteng
# kanser : kanser
# utama : utama
# seawal : awal
# elakkan : elak
# kelak : kelak
# kpd : kpd
# kerana : rana
# melawan : lawan
# lho : lho
# setau : tau
# maaf : maaf
# belajar : ajar
# klw : klw
# doang : doang
# resep : resep
# skrg : skrg
# tequilla : tequilla
# grgr : grgr
# hook : hook
# stranger : stranger
# anjing : anjing
# majalah : majalah
# family : family
# vol : vol
# hadir : hadir
# hdi : hdi
# one : one
# menyajikan : saji
# artikel : artikel
# tips : tips
# imunitas : imunitas
# senja : senja
# mikrobioma : mikrobioma
# membaca : baca
# sejahterakan : sejahtera
# gagal : gagal
# ginjal : ginjal
# kesian : kesi
# tihati : tihati
# bebs : bebs
# protokol : protokol
# newsinfo : newsinfo
# nyadarnya : nyadarnya
# temen : temen
# keliatan : liat
# warm : warm
# undertone : undertone
# kuliat2 : kuliat2
# tanganku : tangan
# motoran : motor
# sinar : sinar
# matahari : matahari
# pink : pink
# mega : mega
# cbt : cbt
# book : book
# slot : slot
# walk : walk
# dialu : alu
# alukan : alu
# free : free
# sahaja : sahaja
# kit : kit
# gen : gen
# then : then
# bayaran : bayar
# otherwise : otherwise
# nyebarkan : nyebarkan
# ilmiahnya : ilmiah
# cmn : cmn
# seneng : neng
# tangani : tangan
# neger : neger
# seru : seru
# perizinan : izin
# pembiayaan : biaya
# dampak : dampak
# pengelolaan : kelola
# limbah : limbah
# terkelola : kelola
# pencemaran : cemar
# tertusuk : tusuk
# benda : benda
# tajam : tajam
# faktor : faktor
# giat : giat
# seklur : seklur
# mengikuti : ikut
# kelruaahn : kelruaahn
# kantor : kantor
# korona : korona
# divaksinasi : vaksinasi
# padaaaa : padaaaa
# lindungi : lindung
# nct : nct
# barengan : bareng
# takutt : takutt
# gapapa : gapapa
# {'dok': 'dok', 'tanya': 'tanya', 'kalau': 'kalau', 'tes': 'tes', 'hepatitis': 'hepatitis', 'sgot': 'sgot', 'sgpt': 'sgpt', 'ningkat': 'ningkat', 'kenapa': 'kenapa', 'terbaik': 'baik', 'teraman': 'ram', 'supplement': 'supplement', 'kesehatan': 'sehat', 'kapsul': 'kapsul', 'spirulina': 'spirulina', 'kolesterol': 'kolesterol', 'diabetes': 'diabetes', 'jantung': 'jantung', 'kapsulspirulina': 'kapsulspirulina', 'herbalspirulina': 'herbalspirulina', 'obat herbal': 'obat herbal', 'suplemen kesehatan': 'suplemen sehat', 'ketua': 'ketua', 'dpr': 'dpr', 'puan': 'puan', 'maharani': 'maharani', 'menyoroti': 'sorot', 'perhatian': 'perhati', 'khusus': 'khusus', 'sidang': 'sidang', 'kali': 'kali', 'akut': 'akut', 'anak': 'anak', 'masyarakat': 'masyarakat', 'membuktikan': 'bukti', 'betapa': 'betapa', 'pedulinya': 'peduli', 'permasalahan': 'masalah', 'tanah': 'tanah', 'air': 'air', 'harga': 'harga', 'pangan': 'pangan', 'lebaran': 'lebaran', 'pemulihan': 'pulih', 'ekonomi': 'ekonomi', 'pandemi': 'pandemi', 'covid': 'covid', 'mereda': 'reda', 'ambil': 'ambil', 'ujian': 'uji', 'darah': 'darah', 'doktor': 'doktor', 'cantik': 'cantik', 'okay': 'okay', 'hiv': 'hiv', 'negative': 'negative', 'lepas': 'lepas', 'nak': 'nak', 'cari': 'cari', 'duit': 'duit', 'extra': 'extra', 'jual': 'jual', 'vaksin': 'vaksin', 'gak': 'gak', 'salah': 'salah', 'misterius': 'misterius', 'rakyatmelawanmandatory': 'rakyatmelawanmandatory', 'who': 'who', 'laporkan': 'lapor', '920': '920', 'tersebar': 'sebar', 'negara': 'negara', 'klik': 'klik', 'baca': 'baca', 'ramai': 'ramai', 'penyebabnya': 'sebab', 'biar': 'biar', 'peduli': 'peduli', 'gejala': 'gejala', 'penyakit': 'sakit', 'yuk': 'yuk', 'tonton': 'tonton', 'penjelasan': 'jelas', 'lengkap': 'lengkap', 'prof': 'prof', 'hinky': 'hinky', 'hindra': 'hindra', 'irawan': 'irawan', 'satari': 'satar', 'troppaed': 'troppaed', 'video': 'video', 'mulan': 'mulan', 'gunung': 'gunung', 'bye': 'bye', 'gue': 'gue', 'udah': 'udah', 'stres': 'stres', 'minggu': 'minggu', 'kertas': 'kertas', 'jahanam': 'jahanam', 'selamat': 'selamat', 'tinggal': 'tinggal', 'blok': 'blok', 'gastrointestinal': 'gastrointestinal', 'lambung': 'lambung', 'teman': 'teman', 'temannya': 'teman', 'bahas': 'bahas', 'maag': 'maag', 'gerd': 'gerd', 'malnutrisi': 'malnutrisi', 'hemoroid': 'hemoroid', 'appendisitis': 'appendisitis', 'peritonitis': 'peritonitis', 'gila': 'gila', 'memang': 'memang', 'anak-anak': 'anak', 'kena': 'kena', 'orang': 'orang', 'tua': 'tua', 'mudah': 'mudah', 'sakit': 'sakit', 'rilis sehat': 'rilis sehat', 'patogen': 'patogen', 'ditemukan': 'temu', 'pasien': 'pasien', 'perawatan': 'awat', 'kecantikan': 'cantik', 'dibahas': 'bahas', 'jarang': 'jarang', 'kesehatannya': 'sehat', 'pastikan': 'pasti', 'hpv': 'hpv', 'tetanus': 'tetanus', 'cek': 'cek', 'ims': 'ims', 'pre': 'pre', 'marital': 'marital', 'medical': 'medical', 'check': 'check', 'genjot': 'genjot', 'vaksinasi': 'vaksinasi', 'booster': 'booster', 'binda': 'binda', 'jateng': 'jateng', 'menyebabkan': 'sebab', 'terkait': 'kait', '100': '100', 'aman': 'aman', 'peringatkan': 'ingat', 'meningkat': 'tingkat', 'kenali': 'kenal', 'gejalanya': 'gejala', 'mengintai': 'intai', 'bunda': 'bunda', 'pencegahannya': 'cegah', 'benarkan': 'benar', 'adenovirus': 'adenovirus', 'astrazeneca': 'astrazeneca', 'picu': 'picu', 'dokter': 'dokter', 'penyebab': 'sebab', 'herbal': 'herbal', 'medan': 'medan', 'bpom': 'bpom', 'mui': 'mui', 'syariah': 'syariah', 'admin': 'admin', 'pin': 'pin', '545481bb': '545481bb', 'call': 'call', '081269806871': '081269806871', 'pancasila': 'pancasila', 'satukan': 'satu', 'negeri': 'negeri', 'normalisasi': 'normalisasi', 'alkoholik': 'alkoholik', 'biarkan': 'biar', 'kalangan': 'kalang', 'muslim': 'muslim', 'terserah': 'serah', 'agama': 'agama', 'non': 'non', 'islam': 'islam', 'mabok': 'mabok', 'sampe': 'sampe', 'kanker': 'kanker', 'hati': 'hati', 'promokan': 'promokan', 'tutupholywingsindonesia': 'tutupholywingsindonesia', 'gakk': 'gakk', 'ahh': 'ahh', 'ntr': 'ntr', 'terbukti': 'bukti', 'mrna' ...
# ------------------------
# Pandas Apply:   0%|          | 0/899 [00:00<?, ?it/s]

# %%
# Menampilkan data sebanyak 19 data teratas dari DataFrame "data_hepatitis"
data_hepatitis.head(19)
# Out:
#             Waktu Tweet          Username  \
# 0   2022-06-26 16:16:08   base anak open
# 1   2022-06-26 14:02:24    billion store
# 2   2022-06-26 12:19:45           lyndsay
# 3   2022-06-26 12:19:42           lyndsay
# 4   2022-06-26 12:17:25           lyndsay
# 5   2022-06-26 11:20:51            syaza
# 6   2022-06-26 11:17:15    jengkelin say
# 7   2022-06-26 11:08:07      pondok indah
# 8   2022-06-26 11:07:32
# 9   2022-06-26 11:05:22              nawa
# 10  2022-06-26 10:20:14
# 11  2022-06-26 09:24:49  jangantungguhaus
# 12  2022-06-26 09:12:36          inisial
# 13  2022-06-26 08:36:42       hendi putra
# 14  2022-06-26 08:18:06              lina
# 15  2022-06-26 07:23:35    pikiran rakyat
# 16  2022-06-26 07:10:33          oke zone
# 17  2022-06-26 06:35:51   selasar ternate
# 18  2022-06-26 06:35:04   selasar ternate
#
#                                                 Tweet  Sentimen  \
# 0   dok mau tanyaaa kalo misalnya tes hepatitis se...   Neutral
# 1   terbaik teraman supplement kesehatan kapsul sp...  Positive
# 2   ketua dpr puan maharani menyoroti sejumlah hal...  Positive
# 3   puan yang menyoroti hepatitis dan berbagai mac...   Neutral
# 4   puan menyoroti kasus hepatitis akut anak harga...  Positive
# 5   ambil ujian darah doktor kata darah semua cant...  Positive
# 6   vaksin gak pernah salah jadi katakan saja itu ...  Positive
# 7   sempat ramai beberapa waktu lalu hepatitis mis...  Positive
# 8                             mulan hepatitis gunung    Neutral
# 9   byeeee semua bye gue udah stres minggu sama ke...   Neutral
# 10   gila dan itu mmg benar banyak anak2 sudah vak...  Negative
# 11   rilissehat patogen ini paling banyak ditemuka...   Neutral
# 12   kalau perawatan kecantikan udah sering dibaha...  Positive
# 13  genjot vaksinasi booster binda jateng vaksinas...  Positive
# 14  hepatitis tidak terkait dengan vaksin vaksin 1...  Positive
# 15  who peringatkan hepatitis misterius pada anak ...   Neutral
# 16  hepatitis akut masih mengintai bunda ini cara ...  Positive
# 17  benarkan adenovirus astrazeneca picu hepatitis...  Positive
# 18    dokter hepatitis akut tak terkait vaksin covid   Positive
#
#                                    Tweet Case Folding  \
# 0   dok mau tanyaaa kalo misalnya tes hepatitis se...
# 1   terbaik teraman supplement kesehatan kapsul sp...
# 2   ketua dpr puan maharani menyoroti sejumlah hal...
# 3   puan yang menyoroti hepatitis dan berbagai mac...
# 4   puan menyoroti kasus hepatitis akut anak harga...
# 5   ambil ujian darah doktor kata darah semua cant...
# 6   vaksin gak pernah salah jadi katakan saja itu ...
# 7   sempat ramai beberapa waktu lalu hepatitis mis...
# 8                             mulan hepatitis gunung
# 9   byeeee semua bye gue udah stres minggu sama ke...
# 10   gila dan itu mmg benar banyak anak2 sudah vak...
# 11   rilissehat patogen ini paling banyak ditemuka...
# 12   kalau perawatan kecantikan udah sering dibaha...
# 13  genjot vaksinasi booster binda jateng vaksinas...
# 14  hepatitis tidak terkait dengan vaksin vaksin 1...
# 15  who peringatkan hepatitis misterius pada anak ...
# 16  hepatitis akut masih mengintai bunda ini cara ...
# 17  benarkan adenovirus astrazeneca picu hepatitis...
# 18    dokter hepatitis akut tak terkait vaksin covid
#
#                                      Tweet Tokenizing  \
# 0   [dok, mau, tanyaaa, kalo, misalnya, tes, hepat...
# 1   [terbaik, teraman, supplement, kesehatan, kaps...
# 2   [ketua, dpr, puan, maharani, menyoroti, sejuml...
# 3   [puan, yang, menyoroti, hepatitis, dan, berbag...
# 4   [puan, menyoroti, kasus, hepatitis, akut, anak...
# 5   [ambil, ujian, darah, doktor, kata, darah, sem...
# 6   [vaksin, gak, pernah, salah, jadi, katakan, sa...
# 7   [sempat, ramai, beberapa, waktu, lalu, hepatit...
# 8                          [mulan, hepatitis, gunung]
# 9   [byeeee, semua, bye, gue, udah, stres, minggu,...
# 10  [gila, dan, itu, mmg, benar, banyak, anak2, su...
# 11  [rilissehat, patogen, ini, paling, banyak, dit...
# 12  [kalau, perawatan, kecantikan, udah, sering, d...
# 13  [genjot, vaksinasi, booster, binda, jateng, va...
# 14  [hepatitis, tidak, terkait, dengan, vaksin, va...
# 15  [who, peringatkan, hepatitis, misterius, pada,...
# 16  [hepatitis, akut, masih, mengintai, bunda, ini...
# 17  [benarkan, adenovirus, astrazeneca, picu, hepa...
# 18  [dokter, hepatitis, akut, tak, terkait, vaksin...
#
#                                       Tweet Stopwords  \
# 0   [dok, tanyaaa, kalo, tes, hepatitis, sgot, sgp...
# 1   [terbaik, teraman, supplement, kesehatan, kaps...
# 2   [ketua, dpr, puan, maharani, menyoroti, perhat...
# 3   [puan, menyoroti, hepatitis, masyarakat, membu...
# 4   [puan, menyoroti, hepatitis, akut, anak, harga...
# 5   [ambil, ujian, darah, doktor, darah, cantik, c...
# 6   [vaksin, gak, salah, misterius, rakyatmelawanm...
# 7   [ramai, hepatitis, misterius, penyebabnya, bia...
# 8                          [mulan, hepatitis, gunung]
# 9   [byeeee, bye, gue, udah, stres, minggu, kertas...
# 10  [gila, mmg, anak2, vaksin, kena, hepatitis, or...
# 11  [rilissehat, patogen, ditemukan, pasien, hepat...
# 12  [perawatan, kecantikan, udah, dibahas, jarang,...
# 13  [genjot, vaksinasi, booster, binda, jateng, va...
# 14    [hepatitis, terkait, vaksin, vaksin, 100, aman]
# 15  [who, peringatkan, hepatitis, misterius, anak,...
# 16  [hepatitis, akut, mengintai, bunda, pencegahan...
# 17  [benarkan, adenovirus, astrazeneca, picu, hepa...
# 18  [dokter, hepatitis, akut, terkait, vaksin, covid]
#
#                                     Tweet Normalisasi  \
# 0   [dok, tanya, kalau, tes, hepatitis, sgot, sgpt...
# 1   [terbaik, teraman, supplement, kesehatan, kaps...
# 2   [ketua, dpr, puan, maharani, menyoroti, perhat...
# 3   [puan, menyoroti, hepatitis, masyarakat, membu...
# 4   [puan, menyoroti, hepatitis, akut, anak, harga...
# 5   [ambil, ujian, darah, doktor, darah, cantik, k...
# 6   [vaksin, gak, salah, misterius, rakyatmelawanm...
# 7   [ramai, hepatitis, misterius, penyebabnya, bia...
# 8                          [mulan, hepatitis, gunung]
# 9   [bye, bye, gue, udah, stres, minggu, kertas, k...
# 10  [gila, memang, anak-anak, vaksin, kena, hepati...
# 11  [rilis sehat, patogen, ditemukan, pasien, hepa...
# 12  [perawatan, kecantikan, udah, dibahas, jarang,...
# 13  [genjot, vaksinasi, booster, binda, jateng, va...
# 14    [hepatitis, terkait, vaksin, vaksin, 100, aman]
# 15  [who, peringatkan, hepatitis, misterius, anak,...
# 16  [hepatitis, akut, mengintai, bunda, pencegahan...
# 17  [benarkan, adenovirus, astrazeneca, picu, hepa...
# 18  [dokter, hepatitis, akut, terkait, vaksin, covid]
#
#                                        Tweet Stemming
# 0   [dok, tanya, kalau, tes, hepatitis, sgot, sgpt...
# 1   [baik, ram, supplement, sehat, kapsul, spiruli...
# 2   [ketua, dpr, puan, maharani, sorot, perhati, k...
# 3   [puan, sorot, hepatitis, masyarakat, bukti, be...
# 4   [puan, sorot, hepatitis, akut, anak, harga, pa...
# 5   [ambil, uji, darah, doktor, darah, cantik, kol...
# 6   [vaksin, gak, salah, misterius, rakyatmelawanm...
# 7   [ramai, hepatitis, misterius, sebab, biar, ped...
# 8                          [mulan, hepatitis, gunung]
# 9   [bye, bye, gue, udah, stres, minggu, kertas, k...
# 10  [gila, memang, anak, vaksin, kena, hepatitis, ...
# 11    [rilis sehat, patogen, temu, pasien, hepatitis]
# 12  [awat, cantik, udah, bahas, jarang, bahas, awa...
# 13  [genjot, vaksinasi, booster, binda, jateng, va...
# 14       [hepatitis, kait, vaksin, vaksin, 100, aman]
# 15  [who, ingat, hepatitis, misterius, anak, tingk...
# 16             [hepatitis, akut, intai, bunda, cegah]
# 17  [benar, adenovirus, astrazeneca, picu, hepatit...
# 18     [dokter, hepatitis, akut, kait, vaksin, covid]

# %%
"""
Membuat kolom yang bernama "Teks Bersih" pada DataFrame "data_hepatitis" yang telah selesai dilakukan proses text preprocessing.
Kolom "Teks Bersih" didapatkan dari kolom "Tweet Stemming" dan menghilangkan pembatas ([] dan , pada setiap teksnya)
serta menampilkan data sebanyak 4 data teratas
"""
data_hepatitis["Tweet Bersih"] = [" ".join(map(str, i)) for i in data_hepatitis["Tweet Stemming"]]
data_hepatitis.head(4)
# Out:
#            Waktu Tweet          Username  \
# 0  2022-06-26 16:16:08   base anak open
# 1  2022-06-26 14:02:24    billion store
# 2  2022-06-26 12:19:45           lyndsay
# 3  2022-06-26 12:19:42           lyndsay
#
#                                                Tweet  Sentimen  \
# 0  dok mau tanyaaa kalo misalnya tes hepatitis se...   Neutral
# 1  terbaik teraman supplement kesehatan kapsul sp...  Positive
# 2  ketua dpr puan maharani menyoroti sejumlah hal...  Positive
# 3  puan yang menyoroti hepatitis dan berbagai mac...   Neutral
#
#                                   Tweet Case Folding  \
# 0  dok mau tanyaaa kalo misalnya tes hepatitis se...
# 1  terbaik teraman supplement kesehatan kapsul sp...
# 2  ketua dpr puan maharani menyoroti sejumlah hal...
# 3  puan yang menyoroti hepatitis dan berbagai mac...
#
#                                     Tweet Tokenizing  \
# 0  [dok, mau, tanyaaa, kalo, misalnya, tes, hepat...
# 1  [terbaik, teraman, supplement, kesehatan, kaps...
# 2  [ketua, dpr, puan, maharani, menyoroti, sejuml...
# 3  [puan, yang, menyoroti, hepatitis, dan, berbag...
#
#                                      Tweet Stopwords  \
# 0  [dok, tanyaaa, kalo, tes, hepatitis, sgot, sgp...
# 1  [terbaik, teraman, supplement, kesehatan, kaps...
# 2  [ketua, dpr, puan, maharani, menyoroti, perhat...
# 3  [puan, menyoroti, hepatitis, masyarakat, membu...
#
#                                    Tweet Normalisasi  \
# 0  [dok, tanya, kalau, tes, hepatitis, sgot, sgpt...
# 1  [terbaik, teraman, supplement, kesehatan, kaps...
# 2  [ketua, dpr, puan, maharani, menyoroti, perhat...
# 3  [puan, menyoroti, hepatitis, masyarakat, membu...
#
#                                       Tweet Stemming  \
# 0  [dok, tanya, kalau, tes, hepatitis, sgot, sgpt...
# 1  [baik, ram, supplement, sehat, kapsul, spiruli...
# 2  [ketua, dpr, puan, maharani, sorot, perhati, k...
# 3  [puan, sorot, hepatitis, masyarakat, bukti, be...
#
#                                         Tweet Bersih
# 0  dok tanya kalau tes hepatitis sgot sgpt ningka...
# 1  baik ram supplement sehat kapsul spirulina kol...
# 2  ketua dpr puan maharani sorot perhati khusus d...
# 3  puan sorot hepatitis masyarakat bukti betapa p...

# %% [markdown]
# ### 3.7. Mengeluarkan Isi Tweet dari Kolom "Tweet Bersih" untuk Persiapan Proses Visualisasi Data

# %%
# Mengeluarkan isi tweet dari kolom "Tweet Bersih" dari DataFrame "data_hepatitis"
ekstraksi_tweet = " ".join(str(c) for c in data_hepatitis["Tweet Bersih"])
ekstraksi_tweet
# Out:
# 'dok tanya kalau tes hepatitis sgot sgpt ningkat kenapa baik ram supplement sehat kapsul spirulina kolesterol diabetes jantung hepatitis kapsulspirulina herbalspirulina obat herbal suplemen sehat ketua dpr puan maharani sorot perhati khusus dpr sidang kali hepatitis akut anak puan sorot hepatitis masyarakat bukti betapa peduli puan masalah tanah air puan sorot hepatitis akut anak harga pangan lebaran pulih ekonomi pandemi covid reda ambil uji darah doktor darah cantik kolesterol okay hepatitis hiv negative lepas nak cari duit extra jual darah vaksin gak salah misterius rakyatmelawanmandatory who lapor 920 hepatitis akut misterius sebar negara klik baca ramai hepatitis misterius sebab biar peduli gejala sakit yuk tonton jelas lengkap prof hinky hindra irawan satar troppaed video mulan hepatitis gunung bye bye gue udah stres minggu kertas kertas jahanam selamat tinggal blok gastrointestinal selamat tinggal lambung teman teman gue bahas maag gerd hepatitis malnutrisi hemoroid appendisitis peritonitis gila memang anak vaksin kena hepatitis orang tua mudah sakit rilis sehat patogen temu pasien hepatitis awat cantik udah bahas jarang bahas awat sehat pasti udah vaksin hpv tetanus hepatitis cek ims pre marital medical check genjot vaksinasi booster binda jateng vaksinasi covid sebab hepatitis akut hepatitis kait vaksin vaksin 100 aman who ingat hepatitis misterius anak tingkat kenal gejala hepatitis akut intai bunda cegah benar adenovirus astrazeneca picu hepatitis akut dokter hepatitis akut kait vaksin covid adenovirus vaksin astrazeneca sebab hepatitis jual herbal hepatitis medan herbal bpom mui syariah admin pin 545481bb call 081269806871 vaksin kait hepatitis pancasila satu negeri vaksin covid sebab hepatitis pancasila satu negeri hepatitis akut kait vaksin covid pancasila satu negeri normalisasi alkoholik negeri biar kalang orang muslim serah kalau agama non islam mabok sampe hepatitis kanker hati peduli promokan kalang muslim tutupholywingsindonesia gakk ahh ntr kena hepatitis vaksinasi covid bukti sebab hepatitis anak pancasila satu negeri vaksinasi covid bukti sebab hepatitis anak pancasila satu negeri hepatitis akut kait vaksin pancasila satu negeri salah vaksin mrna sebab hepatitis anak pancasila satu negeri rumah sakit vaksin hepatitis nya kosong kejar aja senin pas cek bayi dokter anak jalur pribadi vaksin pas iya vaksin hepatitis nya coba gimana kosong sebab muncul hepatitis pancasila satu negeri hepatitis akut kait vaksin covid pancasila satu negeri hepatitis akut jadi kait vaksin covid pancasila satu negeri adenovirus vaksin astrazaneca sebab hepatitis anak pancasila satu negeri hepatitis akut kait vaksin covid pancasila satu negeri cek fakta yuk vaksin mrna sebab hepatitis anak yuk simak jelas pancasila satu negeri who hepatitis akut jadi kait vaksin covid pancasila satu negeri adenovirus vaksin astrazeneca sebab hepatitis pancasila satu negeri hepatitis akut kait vaksin covid pancasila satu negeri vaksin mrna sebab hepatitis pancasila satu negeri salah vaksin mrna sebab hepatitis anak pancasila satu negeri hubung vaksin covid sakit hepatitis akut vaksin bukti aman manfaat pancasila satu negeri vaksin mrna sebab hepatitis pancasila satu negeri adenovirus padabvaksin asteazeneca sebab hepatitis pancasila satu negeri hebat vaksin sebab hepatitis anak pancasila satu negeri mantap vaksin sebab hepatitis anak pancasila satu negeri oke vaksin sebab hepatitis anak pancasila satu negeri vaksin sebab hepatitis anak pancasila satu negeri putus tular hiv hepatitis spil warga bina lapas leok laksana periksa sehat lengkap kemenkumhamri adenovirus vaksin astrazeneca sebab hepatitis anak pancasila satu negeri kait hepatitis pancasila satu negeri vaksin mrna sebab hepatitis stop panik hepatitis akut misterius anak vaksin covid pancasila satu negeri sebab hepatitis pancasila satu negeri adenovirus vaksin astrazenca sebab hepatitis pancasila satu negeri adenovirus vaksin astrazenca sebab hepatitis pancasila satu negeri pancasila satu n ...

# %%
"""
Melihat isi tweet per kata yang telah dilakukan proses ekstraksi. Proses untuk melihat isi tweet per kata
menggunakan fungsi word_tokenize dari library nltk
"""
word_tokenize_tweets = word_tokenize(ekstraksi_tweet)
word_tokenize_tweets
# Out:
# ['dok',
#  'tanya',
#  'kalau',
#  'tes',
#  'hepatitis',
#  'sgot',
#  'sgpt',
#  'ningkat',
#  'kenapa',
#  'baik',
#  'ram',
#  'supplement',
#  'sehat',
#  'kapsul',
#  'spirulina',
#  'kolesterol',
#  'diabetes',
#  'jantung',
#  'hepatitis',
#  'kapsulspirulina',
#  'herbalspirulina',
#  'obat',
#  'herbal',
#  'suplemen',
#  'sehat',
#  'ketua',
#  'dpr',
#  'puan',
#  'maharani',
#  'sorot',
#  'perhati',
#  'khusus',
#  'dpr',
#  'sidang',
#  'kali',
#  'hepatitis',
#  'akut',
#  'anak',
#  'puan',
#  'sorot',
#  'hepatitis',
#  'masyarakat',
#  'bukti',
#  'betapa',
#  'peduli',
#  'puan',
#  'masalah',
#  'tanah',
#  'air',
#  'puan',
#  'sorot',
#  'hepatitis',
#  'akut',
#  'anak',
#  'harga',
#  'pangan',
#  'lebaran',
#  'pulih',
#  'ekonomi',
#  'pandemi',
#  'covid',
#  'reda',
#  'ambil',
#  'uji',
#  'darah',
#  'doktor',
#  'darah',
#  'cantik',
#  'kolesterol',
#  'okay',
#  'hepatitis',
#  'hiv',
#  'negative',
#  'lepas',
#  'nak',
#  'cari',
#  'duit',
#  'extra',
#  'jual',
#  'darah',
#  'vaksin',
#  'gak',
#  'salah',
#  'misterius',
#  'rakyatmelawanmandatory',
#  'who',
#  'lapor',
#  '920',
#  'hepatitis',
#  'akut',
#  'misterius',
#  'sebar',
#  'negara',
#  'klik',
#  'baca',
#  'ramai',
#  'hepatitis',
#  'misterius',
#  'sebab',
#  'biar',
#  'peduli',
#  'gejala',
#  'sakit',
#  'yuk',
#  'tonton',
#  'jelas',
#  'lengkap',
#  'prof',
#  'hinky',
#  'hindra',
#  'irawan',
#  'satar',
#  'troppaed',
#  'video',
#  'mulan',
#  'hepatitis',
#  'gunung',
#  'bye',
#  'bye',
#  'gue',
#  'udah',
#  'stres',
#  'minggu',
#  'kertas',
#  'kertas',
#  'jahanam',
#  'selamat',
#  'tinggal',
#  'blok',
#  'gastrointestinal',
#  'selamat',
#  'tinggal',
#  'lambung',
#  'teman',
#  'teman',
#  'gue',
#  'bahas',
#  'maag',
#  'gerd',
#  'hepatitis',
#  'malnutrisi',
#  'hemoroid',
#  'appendisitis',
#  'peritonitis',
#  'gila',
#  'memang',
#  'anak',
#  'vaksin',
#  'kena',
#  'hepatitis',
#  'orang',
#  'tua',
#  'mudah',
#  'sakit',
#  'rilis',
#  'sehat',
#  'patogen',
#  'temu',
#  'pasien',
#  'hepatitis',
#  'awat',
#  'cantik',
#  'udah',
#  'bahas',
#  'jarang',
#  'bahas',
#  'awat',
#  'sehat',
#  'pasti',
#  'udah',
#  'vaksin',
#  'hpv',
#  'tetanus',
#  'hepatitis',
#  'cek',
#  'ims',
#  'pre',
#  'marital',
#  'medical',
#  'check',
#  'genjot',
#  'vaksinasi',
#  'booster',
#  'binda',
#  'jateng',
#  'vaksinasi',
#  'covid',
#  'sebab',
#  'hepatitis',
#  'akut',
#  'hepatitis',
#  'kait',
#  'vaksin',
#  'vaksin',
#  '100',
#  'aman',
#  'who',
#  'ingat',
#  'hepatitis',
#  'misterius',
#  'anak',
#  'tingkat',
#  'kenal',
#  'gejala',
#  'hepatitis',
#  'akut',
#  'intai',
#  'bunda',
#  'cegah',
#  'benar',
#  'adenovirus',
#  'astrazeneca',
#  'picu',
#  'hepatitis',
#  'akut',
#  'dokter',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'covid',
#  'adenovirus',
#  'vaksin',
#  'astrazeneca',
#  'sebab',
#  'hepatitis',
#  'jual',
#  'herbal',
#  'hepatitis',
#  'medan',
#  'herbal',
#  'bpom',
#  'mui',
#  'syariah',
#  'admin',
#  'pin',
#  '545481bb',
#  'call',
#  '081269806871',
#  'vaksin',
#  'kait',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'covid',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'normalisasi',
#  'alkoholik',
#  'negeri',
#  'biar',
#  'kalang',
#  'orang',
#  'muslim',
#  'serah',
#  'kalau',
#  'agama',
#  'non',
#  'islam',
#  'mabok',
#  'sampe',
#  'hepatitis',
#  'kanker',
#  'hati',
#  'peduli',
#  'promokan',
#  'kalang',
#  'muslim',
#  'tutupholywingsindonesia',
#  'gakk',
#  'ahh',
#  'ntr',
#  'kena',
#  'hepatitis',
#  'vaksinasi',
#  'covid',
#  'bukti',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksinasi',
#  'covid',
#  'bukti',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'pancasila',
#  'satu',
#  'negeri',
#  'salah',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'rumah',
#  'sakit',
#  'vaksin',
#  'hepatitis',
#  'nya',
#  'kosong',
#  'kejar',
#  'aja',
#  'senin',
#  'pas',
#  'cek',
#  'bayi',
#  'dokter',
#  'anak',
#  'jalur',
#  'pribadi',
#  'vaksin',
#  'pas',
#  'iya',
#  'vaksin',
#  'hepatitis',
#  'nya',
#  'coba',
#  'gimana',
#  'kosong',
#  'sebab',
#  'muncul',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'jadi',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'vaksin',
#  'astrazaneca',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'cek',
#  'fakta',
#  'yuk',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'yuk',
#  'simak',
#  'jelas',
#  'pancasila',
#  'satu',
#  'negeri',
#  'who',
#  'hepatitis',
#  'akut',
#  'jadi',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'vaksin',
#  'astrazeneca',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'salah',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hubung',
#  'vaksin',
#  'covid',
#  'sakit',
#  'hepatitis',
#  'akut',
#  'vaksin',
#  'bukti',
#  'aman',
#  'manfaat',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'padabvaksin',
#  'asteazeneca',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hebat',
#  'vaksin',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'mantap',
#  'vaksin',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'oke',
#  'vaksin',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'putus',
#  'tular',
#  'hiv',
#  'hepatitis',
#  'spil',
#  'warga',
#  'bina',
#  'lapas',
#  'leok',
#  'laksana',
#  'periksa',
#  'sehat',
#  'lengkap',
#  'kemenkumhamri',
#  'adenovirus',
#  'vaksin',
#  'astrazeneca',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'kait',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'stop',
#  'panik',
#  'hepatitis',
#  'akut',
#  'misterius',
#  'anak',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'vaksin',
#  'astrazenca',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'vaksin',
#  'astrazenca',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'pancasila',
#  'satu',
#  'negeri',
#  'stop',
#  'panik',
#  'hepatitis',
#  'akut',
#  'misterius',
#  'anak',
#  'vaksin',
#  'covid',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'fakta',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hubung',
#  'vaksinasi',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'aneh',
#  'kalau',
#  'hubung',
#  'hepatitis',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'fakta',
#  'vaksinasi',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'anak',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'sebab',
#  'hepatitis',
#  'fakta',
#  'pancasila',
#  'satu',
#  'negeri',
#  'probable',
#  'hepatitis',
#  'akut',
#  'indonesia',
#  'patogen',
#  'temu',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'covid',
#  'vaksin',
#  'pancasila',
#  'satu',
#  'adenoviros',
#  'vaksin',
#  'astrazaneca',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'asal',
#  'vaksin',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'lawan',
#  'hoax',
#  'adenovirus',
#  'picu',
#  'hepatitis',
#  'akut',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'kait',
#  'vaksin',
#  'ges',
#  'pancasila',
#  'satu',
#  'negeri',
#  'lawan',
#  'hoax',
#  'putar',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hubung',
#  'vaksin',
#  'covid',
#  'sakit',
#  'hepatitis',
#  'akut',
#  'anak',
#  'tim',
#  'covid',
#  'pasti',
#  'vaksin',
#  'anak',
#  'aman',
#  'sehat',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'covid',
#  'picu',
#  'timbul',
#  'hepatitis',
#  'anak',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'cek',
#  'fakta',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'salah',
#  'dasar',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksinasi',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'vaksin',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'waspadaaa',
#  'hoax',
#  'vaksin',
#  'moderna',
#  'fakta',
#  'aman',
#  'kait',
#  'dgn',
#  'hepatitis',
#  'akut',
#  'waspada',
#  'biasa',
#  'hidup',
#  'bersih',
#  'sehat',
#  'disiplinprokestangkalomicron',
#  'pancasila',
#  'satu',
#  'negara',
#  'hepatitis',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'dokter',
#  'hepatitis',
#  'akut',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hoax',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'kandung',
#  'astrazaneca',
#  'kait',
#  'hepatitis',
#  'akut',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'kait',
#  'vaksinasi',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'sebab',
#  'hepatitis',
#  'anak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'covid',
#  'uji',
#  'amp',
#  'jamin',
#  'aman',
#  'sertifikasi',
#  'mui',
#  'kait',
#  'hepatitis',
#  'akut',
#  'pancasila',
#  'satu',
#  'negri',
#  'kait',
#  'covid19',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'percaya',
#  'hoax',
#  'kait',
#  'vaksin',
#  'astra',
#  'anak',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'adenovirus',
#  'vaksina',
#  'astra',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'astrazaneca',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'vaksin',
#  'mrna',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'sebab',
#  'vaksin',
#  'covid',
#  'simak',
#  'pancasila',
#  'satu',
#  'negeri',
#  'pancasila',
#  'satu',
#  'negeri',
#  'waspada',
#  'hoax',
#  'hepatitis',
#  'menteri',
#  'sehat',
#  'kemenkes',
#  'duga',
#  'hepatitis',
#  'akut',
#  'indonesia',
#  'hasil',
#  'sebab',
#  'kumparannews',
#  'vaksin',
#  'anak',
#  'sebab',
#  'hepatitis',
#  'akut',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'akut',
#  'jadi',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hepatitis',
#  'kait',
#  'vaksin',
#  'covid',
#  'pancasila',
#  'satu',
#  'negeri',
#  'andenovirus',
#  'vaksin',
#  'aztrazeneca',
#  'sebab',
#  'hepatitis',
#  'pancasila',
#  'satu',
#  'negeri',
#  'hmmm',
#  'mah',
#  'masuk',
#  'indikasi',
#  'gugur',
#  'sih',
#  'nder',
#  'kalau',
#  'indo',
#  'make',
#  'sure',
#  'aja',
#  'nnati',
#  'pas',
#  'periksa',
#  'hamil',
#  'kali',
#  'periksa',
#  'triple',
#  'elimination',
#  'hiv',
#  'aids',
#  'sifilis',
#  'hepatitis',
#  'wajib',
#  'periksa',
#  'kasi',
#  'calon',
#  'bayi',
#  'nya',
#  'alhamdulilah',
#  'jarang',
#  'sakit',
#  'sekaliny',
#  'sakit',
#  'drawat',
#  'tumor',
#  'paha',
#  '2010',
#  'tumor',
#  '2015',
#  'hepatitis',
#  '2019',
#  'msh',
#  'observasi',
#  'ttp',
#  'rawat',
#  '2022',
#  'guaa',
#  'jugaa',
#  'ngerasain',
#  'ekpetasi',
#  'gua',
#  'sehat',
#  'cacar',
#  'monyet',
#  'hepatitis',
#  'engga',
#  'yaa',
#  'kurikulum',
#  'merdeka',
#  'lahh',
#  'ini',
#  'wadidawwww',
#  'temu',
#  'hiv',
#  'terapi',
#  'efektik',
#  'jangkau',
#  'virus',
#  'covid',
#  'hepatitis',
#  'influenza',
#  'rabies',
#  'tetanus',
#  'usaha',
#  'janji',
#  'ada',
#  'bukti',
#  'valid',
#  'teliti',
#  'con',
#  ...]

# %%
"""
Melakukan proses perhitungan menggunakan probabilitas berdasarkan total kemunculan kata per kata
menggunakan fungsi FreqDist dari library nltk
"""
from nltk.probability import FreqDist
fqdist_tweets = FreqDist(word_tokenize_tweets)
fqdist_tweets
# Out:
# FreqDist({'hepatitis': 937, 'vaksin': 488, 'akut': 423, 'covid': 300, 'sebab': 263, 'anak': 252, 'kait': 231, 'indonesia': 225, 'ikn': 192, 'satu': 171, ...})

# %%
# Menampilkan isi tweet yang sering muncul sebanyak 300 kata saja
fqdist_tweets.most_common(300)
# Out:
# [('hepatitis', 937),
#  ('vaksin', 488),
#  ('akut', 423),
#  ('covid', 300),
#  ('sebab', 263),
#  ('anak', 252),
#  ('kait', 231),
#  ('indonesia', 225),
#  ('ikn', 192),
#  ('satu', 171),
#  ('ekonomi', 115),
#  ('pancasila', 115),
#  ('negeri', 110),
#  ('misterius', 109),
#  ('vaksinasi', 107),
#  ('hoax', 101),
#  ('sakit', 100),
#  ('nusantara', 97),
#  ('waspada', 94),
#  ('maju', 86),
#  ('mrna', 81),
#  ('kuat', 76),
#  ('g20', 75),
#  ('bangkit', 66),
#  ('fakta', 60),
#  ('aman', 54),
#  ('infrastruktur', 54),
#  ('lonjak', 50),
#  ('dokter', 49),
#  ('sehat', 48),
#  ('cek', 47),
#  ('sejahtera', 44),
#  ('adenovirus', 41),
#  ('duga', 40),
#  ('virus', 37),
#  ('dirgahayu', 36),
#  ('hut61', 36),
#  ('jokowi', 36),
#  ('cermin', 35),
#  ('gejala', 34),
#  ('lengkap', 32),
#  ('hubung', 32),
#  ('astrazeneca', 30),
#  ('picu', 28),
#  ('kemenkes', 27),
#  ('hiv', 26),
#  ('prokes', 26),
#  ('2022', 25),
#  ('hati', 24),
#  ('tdk', 23),
#  ('uji', 22),
#  ('cegah', 22),
#  ('ketat', 22),
#  ('planetsejajar', 22),
#  ('temu', 21),
#  ('isu', 21),
#  ('kena', 20),
#  ('cepat', 20),
#  ('bukti', 19),
#  ('muncul', 19),
#  ('sikap', 19),
#  ('hoaks', 18),
#  ('berat', 18),
#  ('darah', 17),
#  ('amp', 17),
#  ('percaya', 17),
#  ('informasi', 17),
#  ('who', 16),
#  ('yuk', 16),
#  ('nya', 16),
#  ('aja', 16),
#  ('jaga', 16),
#  ('buru', 16),
#  ('salah', 15),
#  ('orang', 15),
#  ('pasien', 15),
#  ('teliti', 14),
#  ('provokasi', 14),
#  ('disinformasi', 14),
#  ('masyarakat', 13),
#  ('udah', 13),
#  ('perintah', 13),
#  ('kuning', 13),
#  ('kelas', 13),
#  ('kalau', 12),
#  ('tes', 12),
#  ('gak', 12),
#  ('probable', 12),
#  ('edar', 12),
#  ('berita', 12),
#  ('tau', 12),
#  ('pandemi', 11),
#  ('lapor', 11),
#  ('negara', 11),
#  ('tinggal', 11),
#  ('mui', 11),
#  ('simak', 11),
#  ('dgn', 11),
#  ('jamin', 11),
#  ('serang', 11),
#  ('simplex', 11),
#  ('makan', 11),
#  ('baca', 10),
#  ('tular', 10),
#  ('timbul', 10),
#  ('sertifikasi', 10),
#  ('wabah', 10),
#  ('bahas', 9),
#  ('jadi', 9),
#  ('astrazaneca', 9),
#  ('sih', 9),
#  ('catat', 9),
#  ('provinsi', 9),
#  ('cmv', 9),
#  ('kelompok', 9),
#  ('penting', 9),
#  ('juni', 9),
#  ('tangkalhoaxvaksincovid', 9),
#  ('sebar', 8),
#  ('patogen', 8),
#  ('pas', 8),
#  ('periksa', 8),
#  ('panik', 8),
#  ('covid19', 8),
#  ('hasil', 8),
#  ('sifilis', 8),
#  ('usia', 8),
#  ('mati', 8),
#  ('sembuh', 8),
#  ('awas', 8),
#  ('ahli', 8),
#  ('halal', 8),
#  ('waspadacovidlengkapivaksin', 8),
#  ('indonesiaopen2022', 8),
#  ('jantung', 7),
#  ('biar', 7),
#  ('jelas', 7),
#  ('tingkat', 7),
#  ('yaa', 7),
#  ('buka', 7),
#  ('kumulatif', 7),
#  ('krn', 7),
#  ('liver', 7),
#  ('infeksi', 7),
#  ('investigasi', 7),
#  ('tangan', 7),
#  ('misteri', 7),
#  ('hai', 7),
#  ('bekas', 7),
#  ('bahaya', 7),
#  ('hadap', 7),
#  ('liat', 7),
#  ('kali', 6),
#  ('gue', 6),
#  ('mudah', 6),
#  ('bunda', 6),
#  ('bayi', 6),
#  ('manfaat', 6),
#  ('lawan', 6),
#  ('hidup', 6),
#  ('bersih', 6),
#  ('cacar', 6),
#  ('hepatitisakut', 6),
#  ('akibat', 6),
#  ('punca', 6),
#  ('jangkit', 6),
#  ('kondisi', 6),
#  ('jakarta', 6),
#  ('gitu', 6),
#  ('jgn', 6),
#  ('banget', 6),
#  ('klo', 6),
#  ('beda', 6),
#  ('org', 6),
#  ('dampak', 6),
#  ('walid', 6),
#  ('obat', 5),
#  ('selamat', 5),
#  ('pasti', 5),
#  ('kenal', 5),
#  ('dasar', 5),
#  ('kandung', 5),
#  ('menteri', 5),
#  ('masuk', 5),
#  ('rawat', 5),
#  ('total', 5),
#  ('kabar', 5),
#  ('lingkung', 5),
#  ('turun', 5),
#  ('update', 5),
#  ('donor', 5),
#  ('kota', 5),
#  ('kak', 5),
#  ('sosialisasi', 5),
#  ('bgt', 5),
#  ('ama', 5),
#  ('takut', 5),
#  ('garuda', 5),
#  ('and', 5),
#  ('mere', 5),
#  ('kolesterol', 4),
#  ('puan', 4),
#  ('nak', 4),
#  ('cari', 4),
#  ('awat', 4),
#  ('hpv', 4),
#  ('tetanus', 4),
#  ('coba', 4),
#  ('putar', 4),
#  ('astra', 4),
#  ('mah', 4),
#  ('hamil', 4),
#  ('aids', 4),
#  ('tumor', 4),
#  ('monyet', 4),
#  ('ada', 4),
#  ('sumbang', 4),
#  ('dunia', 4),
#  ('giat', 4),
#  ('ayo', 4),
#  ('unggah', 4),
#  ('mata', 4),
#  ('nama', 4),
#  ('kanak', 4),
#  ('bener', 4),
#  ('tanggap', 4),
#  ('sayang', 4),
#  ('klaim', 4),
#  ('tambah', 4),
#  ('info', 4),
#  ('moga', 4),
#  ('dapet', 4),
#  ('hepatitismisterius', 4),
#  ('mending', 4),
#  ('kayak', 4),
#  ('program', 4),
#  ('kerja', 4),
#  ('efek', 4),
#  ('imunisasi', 4),
#  ('lab', 4),
#  ('suara', 4),
#  ('status', 4),
#  ('bunuh', 4),
#  ('malaria', 4),
#  ('medis', 4),
#  ('cancer', 4),
#  ('the', 4),
#  ('ragu', 4),
#  ('kembang', 4),
#  ('test', 4),
#  ('dpt', 4),
#  ('jenis', 4),
#  ('tubuh', 4),
#  ('nih', 4),
#  ('utk', 4),
#  ('waspadaomicronba4ba5', 4),
#  ('desawisatanusantara', 4),
#  ('seng', 4),
#  ('lupa', 4),
#  ('upaya', 4),
#  ('april', 4),
#  ('bilang', 4),
#  ('lurah', 4),
#  ('kulit', 4),
#  ('warna', 4),
#  ('hindar', 4),
#  ('deteksi', 4),
#  ('riaudamai', 4),
#  ('pti', 4),
#  ('kih', 4),
#  ('organ', 4),
#  ('point', 4),
#  ('diabetes', 3),
#  ('herbal', 3),
#  ('sorot', 3),
#  ('peduli', 3),
#  ('ambil', 3),
#  ('duit', 3),
#  ('jual', 3),
#  ('920', 3),
#  ('ramai', 3),
#  ('prof', 3),
#  ('tua', 3),
#  ('check', 3),
#  ('benar', 3),
#  ('kalang', 3),
#  ('non', 3),
#  ('sampe', 3),
#  ('rumah', 3),
#  ('laksana', 3),
#  ('tim', 3),
#  ('moderna', 3),
#  ('gua', 3),
#  ('rabies', 3),
#  ('bawa', 3),
#  ('ilmuwan', 3),
#  ('900', 3),
#  ('herpes', 3),
#  ('rakyat', 3),
#  ('batalyon', 3)]

# %% [markdown]
# Berdasarkan hasil output diatas dapat diketahui bahwa kata hepatitis merupakan kata yang sering muncul di dalam DataFrame "data_hepatitis" dengan total kemunculan sebanyak 937 kata. Selain kata hepatitis ada kata vaksin yang memiliki total kemunculan sebanyak 488 kata. Selanjutnya adalah kata akut yang memiliki total kemunculan sebanyak 423 kata, dst.

# %% [markdown]
# ## 4. Data Visualisasi

# %%
"""
Melihat total nilai dari kata per kata yang sering muncul berdasarkan
variabel fqdist_tweets menggunakan grafik garis (line plot) dan hanya menampilkan sebanyak 50 kata
"""
plt.figure(figsize=(13, 7))

plt.title("Visualisasi Kata Yang Sering Digunakan di Dalam Tweet Hepatitis Akut", fontsize=14, pad=14)
fqdist_tweets.plot(50, cumulative=False)
plt.show()

# %% [markdown]
# Berdasarkan grafik diatas menunjukkan kata-kata yang sering digunakan dalam meng-tweet terhadap topik hepatitis akut di media sosial twitter. Namun tidak semua kata ditampilkan didalam grafik melainkan hanya 50 kata yang sering digunakan untuk meng-tweet terhadap topik hepatitis akut.

# %%
# Melihat perbandingan antar label sentimen yang ada di dalam DataFrame "data_hepatitis"
plt.figure(figsize=(13, 7))

sns.countplot(x="Sentimen", hue="Sentimen", data=data_hepatitis)
plt.title("Perbandingan antar Label Sentimen terhadap Topik Hepatitis Akut dari Media Sosial Twitter \n"
          "(Positive, Neutral, Negative)", fontsize=14, pad=14)
plt.xlabel("Label Sentimen")
plt.ylabel("Jumlah Nilai")
plt.show()

# %% [markdown]
# Berdasarkan grafik batang diatas dapat diketahui bahwa Label Sentimen yang mendominasi terhadap topik hepatitis akut adalah sentimen Positive sebayak 558 tweet. Contoh tweet yang memiliki label sentimen Positive adalah ketika ketua DPR memberikan respon terhadap hepatitis akut terhadap anak sehingga topik hepatitis akut terhadap anak mendapat perhatian khusus di masa sidang. Kemudian sentimen positive yang diberikan oleh warganet twitter adalah seperti warganet memberikan informasi kalau kegiatan vaksinasi booster tidak menyebabkan terjadinya penyakit hepatitis akut, dst. Mayoritas sentimen negatif diisi oleh tweet-tweet yang menyatakan informasi benar dan sesuai fakta, dukungan agar mau melakukan vaksin booster agar terhindar dari hepatitis akut, ucapan terima kasih, doa dan dukunga antar sesama warganet twitter, dll.
#
# Label sentimen terbanyak kedua setelah Positive adalah Neutral (netral) yang berjumlah sebanyak 243 tweet. Contoh dari tweet netral yang diberikan oleh warganet twitter adalah "mulan hepatitis gunung", "adenovirus pada vaksin astrazeneca bukan penyebab hepatitis", dst. Mayoritas sentimen netral merupakan tweet-tweet yang tidak memiliki keterkaitan dengan hepatitis akut, dll.
#
# Terakhir adalah label sentimen Negative yang memiliki jumlah tweet hanya 98 saja. Contoh tweet-tweet yang bernilai negatif terhadap topik hepatitis akut adalah "benarkah vaksin menyebabkan hepatitis. ini faktanya pancasila satukan negeri", "waspada hoax beredar unggahan yang menyatakan bahwa vaksin mrna menyebabkan hepatitis pada anak infrastruktur satukan nusantara", dst. Sentimen negatif rata-rata didominasi oleh tweet-tweet yang tidak benar (hoax), menimbulkan ketakutan warganet, dll.

# %%
"""
Menampilkan sekaligus memvisualisasikan kata menggunakan grafik wordcloud
dari DataFrame "data_hepatitis" terhadap kolom "Tweet Bersih"
"""
plt.figure(figsize=(13, 7))

all_tweets = " ".join(word for word in data_hepatitis["Tweet Bersih"])
wordcloud = WordCloud(colormap="RdGy", width=650, height=400, 
                      mode="RGBA", background_color="lightgrey").generate(all_tweets)
plt.title("Menampilkan Setiap Kata dari Tweet Warganet terhadap Topik Hepatitis Akut", fontsize=14, pad=14)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Jika dilihat dari grafik diatas merupakan hasil dari wordcloud grafik yang bertujuan untuk mendapatkan insight pemahaman secara utuh tentang suatu ide atau gagasan dari seseorang atau tulisan seseorang dalam suatu waktu tertentu. Visualsasi ini banyak sekali digunakan dalam pengujian analisa sentimen karena untuk melihat setiap kata per kata yang di tweet oleh warganet twitter terhadap suatu topik permasalahan.
#
# Namun hasil grafik diatas masih mencakup semua label sentimen (baik sentimen positif, netral, dan negatif) yang membuat saya kesulitan untuk mengetahui kata-kata mana yang bernilai sentimen publik yang positif, sentimen publik yang netral, dan sentimen publik yang negatif. Maka dari itu untuk memudahkan dalam membedakannya saya akan membuat grafik WordCloud kembali yang mencakup grafik WordCloud untuk sentimen positif, grafik WordCloud untuk sentimen netral, dan grafik WordCloud untuk sentimen negatif.

# %%
# Memisahkan semua tweet yang memiliki label sentimen positif berdasarkan dari kolom "Sentimen" dan menampilkan 7 data teratas
data_hepatitis_sentimen_positif = data_hepatitis[data_hepatitis.Sentimen == "Positive"]
data_hepatitis_sentimen_positif.head(7)
# Out:
#             Waktu Tweet        Username  \
# 1   2022-06-26 14:02:24  billion store
# 2   2022-06-26 12:19:45         lyndsay
# 4   2022-06-26 12:17:25         lyndsay
# 5   2022-06-26 11:20:51          syaza
# 6   2022-06-26 11:17:15  jengkelin say
# 7   2022-06-26 11:08:07    pondok indah
# 12  2022-06-26 09:12:36        inisial
#
#                                                 Tweet  Sentimen  \
# 1   terbaik teraman supplement kesehatan kapsul sp...  Positive
# 2   ketua dpr puan maharani menyoroti sejumlah hal...  Positive
# 4   puan menyoroti kasus hepatitis akut anak harga...  Positive
# 5   ambil ujian darah doktor kata darah semua cant...  Positive
# 6   vaksin gak pernah salah jadi katakan saja itu ...  Positive
# 7   sempat ramai beberapa waktu lalu hepatitis mis...  Positive
# 12   kalau perawatan kecantikan udah sering dibaha...  Positive
#
#                                    Tweet Case Folding  \
# 1   terbaik teraman supplement kesehatan kapsul sp...
# 2   ketua dpr puan maharani menyoroti sejumlah hal...
# 4   puan menyoroti kasus hepatitis akut anak harga...
# 5   ambil ujian darah doktor kata darah semua cant...
# 6   vaksin gak pernah salah jadi katakan saja itu ...
# 7   sempat ramai beberapa waktu lalu hepatitis mis...
# 12   kalau perawatan kecantikan udah sering dibaha...
#
#                                      Tweet Tokenizing  \
# 1   [terbaik, teraman, supplement, kesehatan, kaps...
# 2   [ketua, dpr, puan, maharani, menyoroti, sejuml...
# 4   [puan, menyoroti, kasus, hepatitis, akut, anak...
# 5   [ambil, ujian, darah, doktor, kata, darah, sem...
# 6   [vaksin, gak, pernah, salah, jadi, katakan, sa...
# 7   [sempat, ramai, beberapa, waktu, lalu, hepatit...
# 12  [kalau, perawatan, kecantikan, udah, sering, d...
#
#                                       Tweet Stopwords  \
# 1   [terbaik, teraman, supplement, kesehatan, kaps...
# 2   [ketua, dpr, puan, maharani, menyoroti, perhat...
# 4   [puan, menyoroti, hepatitis, akut, anak, harga...
# 5   [ambil, ujian, darah, doktor, darah, cantik, c...
# 6   [vaksin, gak, salah, misterius, rakyatmelawanm...
# 7   [ramai, hepatitis, misterius, penyebabnya, bia...
# 12  [perawatan, kecantikan, udah, dibahas, jarang,...
#
#                                     Tweet Normalisasi  \
# 1   [terbaik, teraman, supplement, kesehatan, kaps...
# 2   [ketua, dpr, puan, maharani, menyoroti, perhat...
# 4   [puan, menyoroti, hepatitis, akut, anak, harga...
# 5   [ambil, ujian, darah, doktor, darah, cantik, k...
# 6   [vaksin, gak, salah, misterius, rakyatmelawanm...
# 7   [ramai, hepatitis, misterius, penyebabnya, bia...
# 12  [perawatan, kecantikan, udah, dibahas, jarang,...
#
#                                        Tweet Stemming  \
# 1   [baik, ram, supplement, sehat, kapsul, spiruli...
# 2   [ketua, dpr, puan, maharani, sorot, perhati, k...
# 4   [puan, sorot, hepatitis, akut, anak, harga, pa...
# 5   [ambil, uji, darah, doktor, darah, cantik, kol...
# 6   [vaksin, gak, salah, misterius, rakyatmelawanm...
# 7   [ramai, hepatitis, misterius, sebab, biar, ped...
# 12  [awat, cantik, udah, bahas, jarang, bahas, awa...
#
#                                          Tweet Bersih
# 1   baik ram supplement sehat kapsul spirulina kol...
# 2   ketua dpr puan maharani sorot perhati khusus d...
# 4   puan sorot hepatitis akut anak harga pangan le...
# 5   ambil uji darah doktor darah cantik kolesterol...
# 6   vaksin gak salah misterius rakyatmelawanmandat...
# 7   ramai hepatitis misterius sebab biar peduli ge...
# 12  awat cantik udah bahas jarang bahas awat sehat...

# %%
"""
Memvisualisasikan hasil tweet bersih terhadap sentimen positif menggunakan
grafik WordCloud terhadap variabel "data_hepatitis_sentimen_positif"
"""
plt.figure(figsize=(13, 7))

all_tweets_positive = " ".join(word for word in data_hepatitis_sentimen_positif["Tweet Bersih"])
wordcloud = WordCloud(colormap="RdBu", width=650, height=400, 
                      mode="RGBA", background_color="lightgrey").generate(all_tweets_positive)
plt.title("Menampilkan Setiap Kata yang Memiliki Sentimen \n Positive dari Tweet Warganet terhadap Topik Hepatitis Akut",
          fontsize=14, pad=14)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Kata-kata yang ada di dalam WordCloud diatas merupakan kata-kata yang berasal dari sentimen warganet twitter yang hanya bernilai positif sedangkan sentimen seperti netral maupun negatif tidak termasuk didalamnya karena grafik diatas memanggil variabel "data_hepatitis_sentimen_positif" yang otomatis di dalam variabel tersebut diisi oleh tweet-tweet yang memiliki label sentimen positif sedangkan sentimen netral maupun negatif tidak ada didalamnya. Hal tersebut dikarenakan masing-masing sentimen telah dipisahkan dan tentu saja grafik WordCloud-nya juga akan terpisah per masing-masing label sentimen.

# %%
# Memisahkan semua tweet yang memiliki label sentimen netral berdasarkan dari kolom "Sentimen"
data_hepatitis_sentimen_netral = data_hepatitis[data_hepatitis.Sentimen == "Neutral"]
data_hepatitis_sentimen_netral.tail()
# Out:
#              Waktu Tweet          Username  \
# 890  2022-06-17 02:19:20      askadi pijay
# 891  2022-06-17 02:16:51  ujang frusciante
# 892  2022-06-17 02:14:14         hermionne
# 893  2022-06-17 02:12:54     anisa cenceni
# 896  2022-06-17 02:03:05      dindu nuffin
#
#                                                  Tweet Sentimen  \
# 890  ikn sejahterakan negeri jangan percaya hoax va...  Neutral
# 891  ikn sejahterakan negeri waspada informasi hoax...  Neutral
# 892  ikn sejahterakan negeri waspada disinformasi d...  Neutral
# 893   disinformasi vaksin mrna menyebabkan hepatiti...  Neutral
# 896  kandungan adenovirus pada vaksin covid bukan p...  Neutral
#
#                                     Tweet Case Folding  \
# 890  ikn sejahterakan negeri jangan percaya hoax va...
# 891  ikn sejahterakan negeri waspada informasi hoax...
# 892  ikn sejahterakan negeri waspada disinformasi d...
# 893   disinformasi vaksin mrna menyebabkan hepatiti...
# 896  kandungan adenovirus pada vaksin covid bukan p...
#
#                                       Tweet Tokenizing  \
# 890  [ikn, sejahterakan, negeri, jangan, percaya, h...
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 896  [kandungan, adenovirus, pada, vaksin, covid, b...
#
#                                        Tweet Stopwords  \
# 890  [ikn, sejahterakan, negeri, percaya, hoax, vak...
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 896  [kandungan, adenovirus, vaksin, covid, penyeba...
#
#                                      Tweet Normalisasi  \
# 890  [ikn, sejahterakan, negeri, percaya, hoax, vak...
# 891  [ikn, sejahterakan, negeri, waspada, informasi...
# 892  [ikn, sejahterakan, negeri, waspada, disinform...
# 893  [disinformasi, vaksin, mrna, menyebabkan, hepa...
# 896  [kandungan, adenovirus, vaksin, covid, penyeba...
#
#                                         Tweet Stemming  \
# 890  [ikn, sejahtera, negeri, percaya, hoax, vaksin...
# 891  [ikn, sejahtera, negeri, waspada, informasi, h...
# 892  [ikn, sejahtera, negeri, waspada, disinformasi...
# 893  [disinformasi, vaksin, mrna, sebab, hepatitis,...
# 896  [kandung, adenovirus, vaksin, covid, sebab, mu...
#
#                                           Tweet Bersih
# 890  ikn sejahtera negeri percaya hoax vaksin covid...
# 891  ikn sejahtera negeri waspada informasi hoax ka...
# 892  ikn sejahtera negeri waspada disinformasi hoax...
# 893  disinformasi vaksin mrna sebab hepatitis padaa...
# 896  kandung adenovirus vaksin covid sebab muncul h...

# %%
"""
Memvisualisasikan hasil tweet bersih terhadap sentimen netral menggunakan
grafik WordCloud terhadap variabel "data_hepatitis_sentimen_netral"
"""
plt.figure(figsize=(13, 7))

all_tweets_neutral = " ".join(word for word in data_hepatitis_sentimen_netral["Tweet Bersih"])
wordcloud = WordCloud(colormap="Reds", width=650, height=400, 
                      mode="RGBA", background_color="lightgrey").generate(all_tweets_neutral)
plt.title("Menampilkan Setiap Kata yang Memiliki Sentimen \n Neutral dari Tweet Warganet terhadap Topik Hepatitis Akut",
          fontsize=14, pad=14)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Kata-kata yang ada di dalam WordCloud diatas merupakan kata-kata yang berasal dari sentimen warganet twitter yang hanya bernilai netral sedangkan sentimen seperti positif maupun negatif tidak termasuk didalamnya karena grafik diatas memanggil variabel "data_hepatitis_sentimen_netral" yang otomatis di dalam variabel tersebut diisi oleh tweet-tweet yang memiliki label sentimen netral sedangkan sentimen positif maupun negatif tidak ada didalamnya. Hal tersebut dikarenakan masing-masing sentimen telah dipisahkan dan tentu saja grafik WordCloud-nya juga akan terpisah per masing-masing label sentimen.

# %%
# Memisahkan semua tweet yang memiliki label sentimen negatif berdasarkan dari kolom "Sentimen"
data_hepatitis_sentimen_negatif = data_hepatitis[data_hepatitis.Sentimen == "Negative"]
data_hepatitis_sentimen_negatif.head()
# Out:
#             Waktu Tweet             Username  \
# 10  2022-06-26 10:20:14
# 24  2022-06-26 05:15:47  jack kahuna laguna
# 29  2022-06-26 04:47:35        danilla hasan
# 30  2022-06-26 04:37:05  danceeatsleeprepeat
# 41  2022-06-26 03:51:13    julfian mahardika
#
#                                                 Tweet  Sentimen  \
# 10   gila dan itu mmg benar banyak anak2 sudah vak...  Negative
# 24  normalisasi alkoholik negeri ini tidak akan pe...  Negative
# 29   salah vaksin mrna menyebabkan hepatitis pada ...  Negative
# 30   rumah sakit vaksin hepatitis nya sedang koson...  Negative
# 41   salah vaksin mrna menyebabkan hepatitis pada ...  Negative
#
#                                    Tweet Case Folding  \
# 10   gila dan itu mmg benar banyak anak2 sudah vak...
# 24  normalisasi alkoholik negeri ini tidak akan pe...
# 29   salah vaksin mrna menyebabkan hepatitis pada ...
# 30   rumah sakit vaksin hepatitis nya sedang koson...
# 41   salah vaksin mrna menyebabkan hepatitis pada ...
#
#                                      Tweet Tokenizing  \
# 10  [gila, dan, itu, mmg, benar, banyak, anak2, su...
# 24  [normalisasi, alkoholik, negeri, ini, tidak, a...
# 29  [salah, vaksin, mrna, menyebabkan, hepatitis, ...
# 30  [rumah, sakit, vaksin, hepatitis, nya, sedang,...
# 41  [salah, vaksin, mrna, menyebabkan, hepatitis, ...
#
#                                       Tweet Stopwords  \
# 10  [gila, mmg, anak2, vaksin, kena, hepatitis, or...
# 24  [normalisasi, alkoholik, negeri, biarkan, kala...
# 29  [salah, vaksin, mrna, menyebabkan, hepatitis, ...
# 30  [rumah, sakit, vaksin, hepatitis, nya, kosong,...
# 41  [salah, vaksin, mrna, menyebabkan, hepatitis, ...
#
#                                     Tweet Normalisasi  \
# 10  [gila, memang, anak-anak, vaksin, kena, hepati...
# 24  [normalisasi, alkoholik, negeri, biarkan, kala...
# 29  [salah, vaksin, mrna, menyebabkan, hepatitis, ...
# 30  [rumah, sakit, vaksin, hepatitis, nya, kosong,...
# 41  [salah, vaksin, mrna, menyebabkan, hepatitis, ...
#
#                                        Tweet Stemming  \
# 10  [gila, memang, anak, vaksin, kena, hepatitis, ...
# 24  [normalisasi, alkoholik, negeri, biar, kalang,...
# 29  [salah, vaksin, mrna, sebab, hepatitis, anak, ...
# 30  [rumah, sakit, vaksin, hepatitis, nya, kosong,...
# 41  [salah, vaksin, mrna, sebab, hepatitis, anak, ...
#
#                                          Tweet Bersih
# 10  gila memang anak vaksin kena hepatitis orang t...
# 24  normalisasi alkoholik negeri biar kalang orang...
# 29  salah vaksin mrna sebab hepatitis anak pancasi...
# 30  rumah sakit vaksin hepatitis nya kosong kejar ...
# 41  salah vaksin mrna sebab hepatitis anak pancasi...

# %%
"""
Memvisualisasikan hasil tweet bersih terhadap sentimen negatif menggunakan
grafik WordCloud terhadap variabel "data_hepatitis_sentimen_negatif"
"""
plt.figure(figsize=(13, 7))

all_tweets_negative = " ".join(word for word in data_hepatitis_sentimen_negatif["Tweet Bersih"])
wordcloud = WordCloud(colormap="Oranges", width=650, height=400, 
                      mode="RGBA", background_color="lightgrey").generate(all_tweets_negative)
plt.title("Menampilkan Setiap Kata yang Memiliki Sentimen \n Negative dari Tweet Warganet terhadap Topik Hepatitis Akut",
          fontsize=14, pad=14)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Kata-kata yang ada di dalam WordCloud diatas merupakan kata-kata yang berasal dari sentimen warganet twitter yang hanya bernilai negatif sedangkan sentimen seperti positif maupun netral tidak termasuk didalamnya karena grafik diatas memanggil variabel "data_hepatitis_sentimen_negatif" yang otomatis di dalam variabel tersebut diisi oleh tweet-tweet yang memiliki label sentimen negatif saja sedangkan sentimen positif maupun netral tidak ada didalamnya. Hal tersebut dikarenakan masing-masing sentimen telah dipisahkan dan tentu saja grafik WordCloud-nya juga akan terpisah per masing-masing label sentimen.

# %% [markdown]
# ## 5. Pemodelan dengan Algoritma Machine Learning (Naive Bayes & SVM)

# %% [markdown]
# ### 5.1. Pra-Pemodelan
